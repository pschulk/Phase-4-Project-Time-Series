# %%
import pandas as pd

# %%
df = pd.read_csv('data/zillow_data.csv')

# %%
df.head()
# Out:
#    RegionID  RegionName      City State              Metro CountyName  \
# 0     84654       60657   Chicago    IL            Chicago       Cook
# 1     90668       75070  McKinney    TX  Dallas-Fort Worth     Collin
# 2     91982       77494      Katy    TX            Houston     Harris
# 3     84616       60614   Chicago    IL            Chicago       Cook
# 4     93144       79936   El Paso    TX            El Paso    El Paso
#
#    SizeRank   1996-04   1996-05   1996-06  ...  2017-07  2017-08  2017-09  \
# 0         1  334200.0  335400.0  336500.0  ...  1005500  1007500  1007800
# 1         2  235700.0  236900.0  236700.0  ...   308000   310000   312500
# 2         3  210400.0  212200.0  212200.0  ...   321000   320600   320200
# 3         4  498100.0  500900.0  503100.0  ...  1289800  1287700  1287400
# 4         5   77300.0   77300.0   77300.0  ...   119100   119400   120000
#
#    2017-10  2017-11  2017-12  2018-01  2018-02  2018-03  2018-04
# 0  1009600  1013300  1018700  1024400  1030700  1033800  1030600
# 1   314100   315000   316600   318100   319600   321100   321800
# 2   320400   320800   321200   321200   323000   326900   329900
# 3  1291500  1296600  1299000  1302700  1306400  1308500  1307000
# 4   120300   120300   120300   120300   120500   121000   121500
#
# [5 rows x 272 columns]

# %%
df = df.rename(columns={'RegionName': 'zipcode'})

# %%
df['zipcode'] = df['zipcode'].astype(str).str.zfill(5)

# %%
df['five_year'] = ((df['2018-04']/df['2013-04'])-1)*100

# %%
df.head()
# Out:
#    RegionID zipcode      City State              Metro CountyName  SizeRank  \
# 0     84654   60657   Chicago    IL            Chicago       Cook         1
# 1     90668   75070  McKinney    TX  Dallas-Fort Worth     Collin         2
# 2     91982   77494      Katy    TX            Houston     Harris         3
# 3     84616   60614   Chicago    IL            Chicago       Cook         4
# 4     93144   79936   El Paso    TX            El Paso    El Paso         5
#
#     1996-04   1996-05   1996-06  ...  2017-08  2017-09  2017-10  2017-11  \
# 0  334200.0  335400.0  336500.0  ...  1007500  1007800  1009600  1013300
# 1  235700.0  236900.0  236700.0  ...   310000   312500   314100   315000
# 2  210400.0  212200.0  212200.0  ...   320600   320200   320400   320800
# 3  498100.0  500900.0  503100.0  ...  1287700  1287400  1291500  1296600
# 4   77300.0   77300.0   77300.0  ...   119400   120000   120300   120300
#
#    2017-12  2018-01  2018-02  2018-03  2018-04  five_year
# 0  1018700  1024400  1030700  1033800  1030600  26.082701
# 1   316600   318100   319600   321100   321800  53.384175
# 2   321200   321200   323000   326900   329900  28.315830
# 3  1299000  1302700  1306400  1308500  1307000  25.878840
# 4   120300   120300   120500   121000   121500   7.048458
#
# [5 rows x 273 columns]

# %%
df[['zipcode','City','State','five_year']].sort_values(by=['five_year'],ascending=False).head(20)
# Out:
#      zipcode              City State   five_year
# 7302   80216            Denver    CO  173.872951
# 1477   94601           Oakland    CA  167.943262
# 5830   48240           Redford    MI  161.224490
# 1239   94590           Vallejo    CA  159.379310
# 2661   33705  Saint Petersburg    FL  159.210526
# 6105   37210         Nashville    TN  155.932203
# 2627   33460        Lake Worth    FL  153.647059
# 6563   15201        Pittsburgh    PA  147.593583
# 475    11216          New York    NY  147.591761
# 1835   37207         Nashville    TN  146.683047
# 1461   33461      Palm Springs    FL  146.335404
# 1273   33435     Boynton Beach    FL  144.760820
# 990    33415        Greenacres    FL  144.613435
# 2988   32807           Orlando    FL  144.415243
# 4146   33030         Homestead    FL  144.167610
# 1463   34207         Bradenton    FL  141.495601
# 3794   33056     Miami Gardens    FL  140.647858
# 1681   94606           Oakland    CA  140.110269
# 1758   30316           Atlanta    GA  140.088106
# 1946   85035           Phoenix    AZ  139.940387

# %%
lake_worth = df.loc[df['zipcode'] == '48240']

# %%
lake_worth.head()
# Out:
#       RegionID zipcode     City State    Metro CountyName  SizeRank  1996-04  \
# 5830     79095   48240  Redford    MI  Detroit      Wayne      5831  67800.0
#
#       1996-05  1996-06  ...  2017-08  2017-09  2017-10  2017-11  2017-12  \
# 5830  68200.0  68500.0  ...    67100    68100    68700    69700    71000
#
#       2018-01  2018-02  2018-03  2018-04  five_year
# 5830    72300    73500    75300    76800  161.22449
#
# [1 rows x 273 columns]

# %%
lake_worth = lake_worth.iloc[:,7:-1]

# %%
lake_worth.head()
# Out:
#       1996-04  1996-05  1996-06  1996-07  1996-08  1996-09  1996-10  1996-11  \
# 5830  67800.0  68200.0  68500.0  68800.0  69200.0  69500.0  69800.0  70000.0
#
#       1996-12  1997-01  ...  2017-07  2017-08  2017-09  2017-10  2017-11  \
# 5830  70400.0  70800.0  ...    65900    67100    68100    68700    69700
#
#       2017-12  2018-01  2018-02  2018-03  2018-04
# 5830    71000    72300    73500    75300    76800
#
# [1 rows x 265 columns]

# %%
lake_worth = lake_worth.T

# %%
lake_worth.head()
# Out:
#             5830
# 1996-04  67800.0
# 1996-05  68200.0
# 1996-06  68500.0
# 1996-07  68800.0
# 1996-08  69200.0

# %%
type(lake_worth)
# Out:
# pandas.core.frame.DataFrame

# %%
lake_worth = lake_worth.rename(columns={5830:'home price'})

# %%
lake_worth.head()
# Out:
#          home price
# 1996-04     67800.0
# 1996-05     68200.0
# 1996-06     68500.0
# 1996-07     68800.0
# 1996-08     69200.0

# %%
lake_worth.index = lake_worth.index.astype('datetime64[ns]')

# %%
lake_worth.index.dtype
# Out:
# dtype('<M8[ns]')

# %%
lake_worth.plot();

# %%
lake_worth['diff'] = lake_worth.diff()

# %%
lake_worth.head()
# Out:
#             home price   diff
# 1996-04-01     67800.0    NaN
# 1996-05-01     68200.0  400.0
# 1996-06-01     68500.0  300.0
# 1996-07-01     68800.0  300.0
# 1996-08-01     69200.0  400.0

# %%
lake_worth['home price shifted'] = lake_worth['home price'].shift()

# %%
lake_worth.tail()
# Out:
#             home price    diff  home price shifted
# 2017-12-01     71000.0  1300.0             69700.0
# 2018-01-01     72300.0  1300.0             71000.0
# 2018-02-01     73500.0  1200.0             72300.0
# 2018-03-01     75300.0  1800.0             73500.0
# 2018-04-01     76800.0  1500.0             75300.0

# %%
lake_worth['pct'] = lake_worth['diff']/lake_worth['home price shifted']

# %%
lake_worth.head()
# Out:
#             home price   diff  home price shifted       pct
# 1996-04-01     67800.0    NaN                 NaN       NaN
# 1996-05-01     68200.0  400.0             67800.0  0.005900
# 1996-06-01     68500.0  300.0             68200.0  0.004399
# 1996-07-01     68800.0  300.0             68500.0  0.004380
# 1996-08-01     69200.0  400.0             68800.0  0.005814

# %%
lake_worth['5 year shift'] = lake_worth['home price'].shift(60)

# %%
lake_worth.head(61)
# Out:
#             home price    diff  home price shifted       pct  5 year shift
# 1996-04-01     67800.0     NaN                 NaN       NaN           NaN
# 1996-05-01     68200.0   400.0             67800.0  0.005900           NaN
# 1996-06-01     68500.0   300.0             68200.0  0.004399           NaN
# 1996-07-01     68800.0   300.0             68500.0  0.004380           NaN
# 1996-08-01     69200.0   400.0             68800.0  0.005814           NaN
# ...                ...     ...                 ...       ...           ...
# 2000-12-01    101200.0  1200.0            100000.0  0.012000           NaN
# 2001-01-01    102400.0  1200.0            101200.0  0.011858           NaN
# 2001-02-01    103600.0  1200.0            102400.0  0.011719           NaN
# 2001-03-01    104700.0  1100.0            103600.0  0.010618           NaN
# 2001-04-01    105800.0  1100.0            104700.0  0.010506       67800.0
#
# [61 rows x 5 columns]

# %%
lake_worth['5 year return'] = ((lake_worth['home price']/lake_worth['5 year shift'])-1)*100

# %%
lake_worth.tail()
# Out:
#             home price    diff  home price shifted       pct  5 year shift  \
# 2017-12-01     71000.0  1300.0             69700.0  0.018651       27900.0
# 2018-01-01     72300.0  1300.0             71000.0  0.018310       28400.0
# 2018-02-01     73500.0  1200.0             72300.0  0.016598       28600.0
# 2018-03-01     75300.0  1800.0             73500.0  0.024490       28800.0
# 2018-04-01     76800.0  1500.0             75300.0  0.019920       29400.0
#
#             5 year return
# 2017-12-01     154.480287
# 2018-01-01     154.577465
# 2018-02-01     156.993007
# 2018-03-01     161.458333
# 2018-04-01     161.224490

# %%
lake_worth.head()
# Out:
#             home price   diff  home price shifted       pct  5 year shift  \
# 1996-04-01     67800.0    NaN                 NaN       NaN           NaN
# 1996-05-01     68200.0  400.0             67800.0  0.005900           NaN
# 1996-06-01     68500.0  300.0             68200.0  0.004399           NaN
# 1996-07-01     68800.0  300.0             68500.0  0.004380           NaN
# 1996-08-01     69200.0  400.0             68800.0  0.005814           NaN
#
#             5 year return
# 1996-04-01            NaN
# 1996-05-01            NaN
# 1996-06-01            NaN
# 1996-07-01            NaN
# 1996-08-01            NaN

# %%
lw_dvar = lake_worth.dropna()

# %%
df_mean = pd.read_csv('data/national.csv')

# %%
df_mean.head()
# Out:
#           Unnamed: 0          0
# 0  five-year 2001-04  35.180540
# 1  five-year 2001-05  35.760117
# 2  five-year 2001-06  36.308179
# 3  five-year 2001-07  36.831948
# 4  five-year 2001-08  37.328660

# %%
df_mean.iloc[:,1].values
# Out:
# array([ 35.18053985,  35.76011692,  36.30817887,  36.83194827,
#         37.32865988,  37.8069953 ,  38.27221538,  38.73249943,
#         39.111278  ,  39.4460225 ,  39.83724063,  40.30037615,
#         40.72237946,  41.09422992,  41.43360942,  41.74907935,
#         42.04327701,  42.33381627,  42.59648697,  42.99951262,
#         43.39240939,  43.57326369,  43.62538032,  43.80738873,
#         44.01288126,  44.2614003 ,  44.57818087,  44.96467443,
#         45.38097162,  45.81328425,  46.21790364,  46.55667771,
#         46.75474477,  46.89544351,  47.13687621,  47.55439538,
#         48.08249299,  48.73351988,  49.51166504,  50.37375685,
#         51.24110653,  52.09484394,  52.88972001,  53.56845997,
#         54.0826896 ,  54.45101928,  54.77126623,  55.19703608,
#         55.72187368,  56.2947537 ,  56.91857375,  57.56652767,
#         58.15227369,  58.64489454,  58.99356943,  59.1596511 ,
#         59.11005283,  58.88426206,  58.55733692,  58.27644121,
#         58.01882505,  57.71987763,  57.34617398,  56.88177713,
#         56.28417717,  55.57493772,  54.74936412,  53.81686734,
#         52.83386906,  51.82329395,  50.73004778,  49.64242487,
#         48.56133131,  47.41535353,  46.17818837,  44.8967385 ,
#         43.55008563,  42.14554825,  40.68452462,  38.98826574,
#         37.13337659,  35.36919665,  33.67675816,  31.94448508,
#         30.17153582,  28.30469114,  26.32317685,  24.35189182,
#         22.43994641,  20.61612751,  18.87062426,  17.23859908,
#         15.72086628,  14.27883333,  12.78158169,  11.21612255,
#          9.55901455,   7.75626154,   5.90028062,   4.22381977,
#          2.75547556,   1.42573653,   0.20809769,  -0.85699026,
#         -1.81818966,  -2.70467547,  -3.37057566,  -4.23776625,
#         -5.37623841,  -6.38381087,  -7.19705591,  -8.21339982,
#         -9.3242649 , -10.44320118, -11.52275308, -12.56952694,
#        -13.5849791 , -14.52927597, -15.40908083, -16.21922779,
#        -16.92841743, -17.54888875, -18.1221116 , -18.60464081,
#        -18.99311301, -19.31376722, -19.58035029, -19.79378559,
#        -19.98020123, -20.15545673, -20.28153773, -20.29927883,
#        -20.1848498 , -19.95184429, -19.65582478, -19.32095233,
#        -18.95251034, -18.54447235, -18.08623817, -17.54050802,
#        -16.93178614, -16.29044071, -15.56093517, -14.7097567 ,
#        -13.74038068, -12.66169059, -11.48235149, -10.28820384,
#         -9.1499555 ,  -8.10912986,  -7.12673341,  -6.17631668,
#         -5.27705022,  -4.41703672,  -3.50970341,  -2.53625053,
#         -1.45698488,  -0.19854905,   1.11734141,   2.25009727,
#          3.13422916,   3.82499829,   4.39973588,   4.90160896,
#          5.33868265,   5.75351672,   6.01471595,   6.52398799,
#          7.39171167,   8.21684445,   8.81505649,   9.66265571,
#         10.66644064,  11.72729217,  12.7903877 ,  13.90373299,
#         15.0972819 ,  16.36266533,  17.61098535,  18.76314629,
#         19.87733755,  21.05261618,  22.29716737,  23.51015826,
#         24.62820998,  25.65042234,  26.63819342,  27.60527726,
#         28.50614653,  29.40427079,  30.23923857,  30.86539096,
#         31.33546649,  31.78915127,  32.18735   ,  32.53072575,
#         32.90503973,  33.28267069,  33.5877789 ,  33.78443833,
#         33.98138802,  34.14608058,  34.38170443,  34.75969992,
#         34.75328789])

# %%
lw_dvar['mar'] = df_mean.iloc[:,1].values
# Out:
# <ipython-input-51-27c190f2f8ee>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lw_dvar['mar'] = df_mean.iloc[:,1].values

# %%
lw_dvar.tail()
# Out:
#             home price    diff  home price shifted       pct  5 year shift  \
# 2017-12-01     71000.0  1300.0             69700.0  0.018651       27900.0
# 2018-01-01     72300.0  1300.0             71000.0  0.018310       28400.0
# 2018-02-01     73500.0  1200.0             72300.0  0.016598       28600.0
# 2018-03-01     75300.0  1800.0             73500.0  0.024490       28800.0
# 2018-04-01     76800.0  1500.0             75300.0  0.019920       29400.0
#
#             5 year return        mar
# 2017-12-01     154.480287  33.981388
# 2018-01-01     154.577465  34.146081
# 2018-02-01     156.993007  34.381704
# 2018-03-01     161.458333  34.759700
# 2018-04-01     161.224490  34.753288

# %%
lw_dvar['5 year minus mar'] = lw_dvar['5 year return'] - lw_dvar['mar']
# Out:
# <ipython-input-53-0dfe89c527e9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lw_dvar['5 year minus mar'] = lw_dvar['5 year return'] - lw_dvar['mar']

# %%
lw_dvar.head()
# Out:
#             home price    diff  home price shifted       pct  5 year shift  \
# 2001-04-01    105800.0  1100.0            104700.0  0.010506       67800.0
# 2001-05-01    106700.0   900.0            105800.0  0.008507       68200.0
# 2001-06-01    107700.0  1000.0            106700.0  0.009372       68500.0
# 2001-07-01    108400.0   700.0            107700.0  0.006500       68800.0
# 2001-08-01    109100.0   700.0            108400.0  0.006458       69200.0
#
#             5 year return        mar  5 year minus mar
# 2001-04-01      56.047198  35.180540         20.866658
# 2001-05-01      56.451613  35.760117         20.691496
# 2001-06-01      57.226277  36.308179         20.918099
# 2001-07-01      57.558140  36.831948         20.726191
# 2001-08-01      57.658960  37.328660         20.330300

# %%
lw_dvar['5 year minus mar'].plot();

# %%
lw_down = lw_dvar.loc[lw_dvar['5 year minus mar'] < 0]

# %%
lw_down['neg sq'] = lw_down['5 year minus mar']**2
# Out:
# <ipython-input-57-0c89c2b59d50>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lw_down['neg sq'] = lw_down['5 year minus mar']**2

# %%
lw_down.head(60)
# Out:
#             home price    diff  home price shifted       pct  5 year shift  \
# 2003-04-01    115700.0   400.0            115300.0  0.003469       80500.0
# 2003-05-01    116100.0   400.0            115700.0  0.003457       81300.0
# 2003-06-01    116400.0   300.0            116100.0  0.002584       82200.0
# 2003-07-01    116800.0   400.0            116400.0  0.003436       83000.0
# 2003-08-01    117200.0   400.0            116800.0  0.003425       83800.0
# 2003-09-01    117500.0   300.0            117200.0  0.002560       84600.0
# 2003-10-01    117800.0   300.0            117500.0  0.002553       85300.0
# 2003-11-01    118100.0   300.0            117800.0  0.002547       86000.0
# 2003-12-01    118500.0   400.0            118100.0  0.003387       86800.0
# 2004-01-01    119000.0   500.0            118500.0  0.004219       87600.0
# 2004-02-01    119600.0   600.0            119000.0  0.005042       88400.0
# 2004-03-01    120100.0   500.0            119600.0  0.004181       89000.0
# 2004-04-01    120500.0   400.0            120100.0  0.003331       89600.0
# 2004-05-01    120900.0   400.0            120500.0  0.003320       90100.0
# 2004-06-01    121300.0   400.0            120900.0  0.003309       90600.0
# 2004-07-01    121700.0   400.0            121300.0  0.003298       91000.0
# 2004-08-01    122100.0   400.0            121700.0  0.003287       91300.0
# 2004-09-01    122300.0   200.0            122100.0  0.001638       91600.0
# 2004-10-01    122500.0   200.0            122300.0  0.001635       91900.0
# 2004-11-01    122500.0     0.0            122500.0  0.000000       92100.0
# 2004-12-01    122400.0  -100.0            122500.0 -0.000816       92500.0
# 2005-01-01    122300.0  -100.0            122400.0 -0.000817       92900.0
# 2005-02-01    122000.0  -300.0            122300.0 -0.002453       93300.0
# 2005-03-01    121700.0  -300.0            122000.0 -0.002459       93700.0
# 2005-04-01    121600.0  -100.0            121700.0 -0.000822       94100.0
# 2005-05-01    121400.0  -200.0            121600.0 -0.001645       94700.0
# 2005-06-01    121400.0     0.0            121400.0  0.000000       95400.0
# 2005-07-01    121400.0     0.0            121400.0  0.000000       96100.0
# 2005-08-01    121500.0   100.0            121400.0  0.000824       96900.0
# 2005-09-01    121600.0   100.0            121500.0  0.000823       97900.0
# 2005-10-01    121500.0  -100.0            121600.0 -0.000822       98900.0
# 2005-11-01    121300.0  -200.0            121500.0 -0.001646      100000.0
# 2005-12-01    121000.0  -300.0            121300.0 -0.002473      101200.0
# 2006-01-01    120500.0  -500.0            121000.0 -0.004132      102400.0
# 2006-02-01    120100.0  -400.0            120500.0 -0.003320      103600.0
# 2006-03-01    119800.0  -300.0            120100.0 -0.002498      104700.0
# 2006-04-01    119800.0     0.0            119800.0  0.000000      105800.0
# 2006-05-01    119900.0   100.0            119800.0  0.000835      106700.0
# 2006-06-01    120100.0   200.0            119900.0  0.001668      107700.0
# 2006-07-01    120100.0     0.0            120100.0  0.000000      108400.0
# 2006-08-01    119900.0  -200.0            120100.0 -0.001665      109100.0
# 2006-09-01    119600.0  -300.0            119900.0 -0.002502      109700.0
# 2006-10-01    119200.0  -400.0            119600.0 -0.003344      110200.0
# 2006-11-01    118600.0  -600.0            119200.0 -0.005034      110700.0
# 2006-12-01    117900.0  -700.0            118600.0 -0.005902      111200.0
# 2007-01-01    117200.0  -700.0            117900.0 -0.005937      111600.0
# 2007-02-01    116100.0 -1100.0            117200.0 -0.009386      111900.0
# 2007-03-01    115000.0 -1100.0            116100.0 -0.009475      112100.0
# 2007-04-01    114100.0  -900.0            115000.0 -0.007826      112400.0
# 2007-05-01    113100.0 -1000.0            114100.0 -0.008764      112600.0
# 2007-06-01    111700.0 -1400.0            113100.0 -0.012378      112700.0
# 2007-07-01    110100.0 -1600.0            111700.0 -0.014324      112900.0
# 2007-08-01    108400.0 -1700.0            110100.0 -0.015441      113200.0
# 2007-09-01    107000.0 -1400.0            108400.0 -0.012915      113500.0
# 2007-10-01    105800.0 -1200.0            107000.0 -0.011215      113800.0
# 2007-11-01    105000.0  -800.0            105800.0 -0.007561      114100.0
# 2007-12-01    104500.0  -500.0            105000.0 -0.004762      114400.0
# 2008-01-01    103800.0  -700.0            104500.0 -0.006699      114700.0
# 2008-02-01    102500.0 -1300.0            103800.0 -0.012524      115000.0
# 2008-03-01    101100.0 -1400.0            102500.0 -0.013659      115300.0
#
#             5 year return        mar  5 year minus mar       neg sq
# 2003-04-01      43.726708  44.012881         -0.286173     0.081895
# 2003-05-01      42.804428  44.261400         -1.456972     2.122768
# 2003-06-01      41.605839  44.578181         -2.972341     8.834814
# 2003-07-01      40.722892  44.964674         -4.241783    17.992722
# 2003-08-01      39.856802  45.380972         -5.524170    30.516451
# 2003-09-01      38.888889  45.813284         -6.924395    47.947251
# 2003-10-01      38.100821  46.217904         -8.117083    65.887037
# 2003-11-01      37.325581  46.556678         -9.231096    85.213139
# 2003-12-01      36.520737  46.754745        -10.234007   104.734908
# 2004-01-01      35.844749  46.895444        -11.050695   122.117852
# 2004-02-01      35.294118  47.136876        -11.842759   140.250930
# 2004-03-01      34.943820  47.554395        -12.610575   159.026606
# 2004-04-01      34.486607  48.082493        -13.595886   184.848112
# 2004-05-01      34.184240  48.733520        -14.549280   211.681553
# 2004-06-01      33.885210  49.511665        -15.626455   244.186106
# 2004-07-01      33.736264  50.373757        -16.637493   276.806177
# 2004-08-01      33.734940  51.241107        -17.506167   306.465875
# 2004-09-01      33.515284  52.094844        -18.579560   345.200053
# 2004-10-01      33.297062  52.889720        -19.592658   383.872247
# 2004-11-01      33.007600  53.568460        -20.560860   422.748945
# 2004-12-01      32.324324  54.082690        -21.758365   473.426459
# 2005-01-01      31.646932  54.451019        -22.804087   520.026388
# 2005-02-01      30.760986  54.771266        -24.010280   576.493554
# 2005-03-01      29.882604  55.197036        -25.314432   640.820469
# 2005-04-01      29.224230  55.721874        -26.497644   702.125145
# 2005-05-01      28.194298  56.294754        -28.100456   789.635623
# 2005-06-01      27.253669  56.918574        -29.664905   880.006588
# 2005-07-01      26.326743  57.566528        -31.239785   975.924148
# 2005-08-01      25.386997  58.152274        -32.765277  1073.563363
# 2005-09-01      24.208376  58.644895        -34.436519  1185.873816
# 2005-10-01      22.851365  58.993569        -36.142204  1306.258940
# 2005-11-01      21.300000  59.159651        -37.859651  1433.353181
# 2005-12-01      19.565217  59.110053        -39.544835  1563.794010
# 2006-01-01      17.675781  58.884262        -41.208481  1698.138891
# 2006-02-01      15.926641  58.557337        -42.630696  1817.376241
# 2006-03-01      14.422159  58.276441        -43.854283  1923.198108
# 2006-04-01      13.232514  58.018825        -44.786311  2005.813642
# 2006-05-01      12.371134  57.719878        -45.348744  2056.508547
# 2006-06-01      11.513463  57.346174        -45.832711  2100.637366
# 2006-07-01      10.793358  56.881777        -46.088419  2124.142384
# 2006-08-01       9.899175  56.284177        -46.385002  2151.568420
# 2006-09-01       9.024613  55.574938        -46.550325  2166.932771
# 2006-10-01       8.166969  54.749364        -46.582395  2169.919521
# 2006-11-01       7.136405  53.816867        -46.680463  2179.065593
# 2006-12-01       6.025180  52.833869        -46.808689  2191.053385
# 2007-01-01       5.017921  51.823294        -46.805373  2190.742924
# 2007-02-01       3.753351  50.730048        -46.976697  2206.810021
# 2007-03-01       2.586976  49.642425        -47.055449  2214.215276
# 2007-04-01       1.512456  48.561331        -47.048876  2213.596714
# 2007-05-01       0.444050  47.415354        -46.971304  2206.303381
# 2007-06-01      -0.887311  46.178188        -47.065500  2215.161273
# 2007-07-01      -2.480071  44.896739        -47.376809  2244.562065
# 2007-08-01      -4.240283  43.550086        -47.790368  2283.919303
# 2007-09-01      -5.726872  42.145548        -47.872421  2291.768645
# 2007-10-01      -7.029877  40.684525        -47.714402  2276.664120
# 2007-11-01      -7.975460  38.988266        -46.963726  2205.591547
# 2007-12-01      -8.653846  37.133377        -45.787223  2096.469767
# 2008-01-01      -9.503051  35.369197        -44.872248  2013.518648
# 2008-02-01     -10.869565  33.676758        -44.546323  1984.374926
# 2008-03-01     -12.315698  31.944485        -44.260183  1958.963822

# %%
lw_down.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 143 entries, 2003-04-01 to 2015-02-01
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   home price          143 non-null    float64
#  1   diff                143 non-null    float64
#  2   home price shifted  143 non-null    float64
#  3   pct                 143 non-null    float64
#  4   5 year shift        143 non-null    float64
#  5   5 year return       143 non-null    float64
#  6   mar                 143 non-null    float64
#  7   5 year minus mar    143 non-null    float64
#  8   neg sq              143 non-null    float64
# dtypes: float64(9)
# memory usage: 11.2 KB

# %%
import numpy as np

np.sqrt(lw_down['neg sq'].sum()/lw_down['neg sq'].count())
# Out:
# 44.72101512467744

# %%
lw_var = lake_worth['5 year return'].dropna()

# %%
lw_var.std()
# Out:
# 85.07622645166362

# %%
lw_var.mean()
# Out:
# 54.0368829557541

# %%
lw_var.describe()
# Out:
# count    206.000000
# mean      53.871655
# std       84.901596
# min      -71.832123
# 25%      -33.036036
# 50%       57.167779
# 75%      124.909945
# max      192.718999
# Name: 5 year return, dtype: float64

# %%
lw_var.plot();

# %%
lake_worth = lake_worth.dropna()

# %%
lake_worth.head()
# Out:
#             home price   diff  home price shifted       pct
# 1996-05-01     59900.0  100.0             59800.0  0.001672
# 1996-06-01     60000.0  100.0             59900.0  0.001669
# 1996-07-01     60200.0  200.0             60000.0  0.003333
# 1996-08-01     60400.0  200.0             60200.0  0.003322
# 1996-09-01     60700.0  300.0             60400.0  0.004967

# %%
lake_worth_pct = lake_worth.drop(['home price','diff','home price shifted'],axis=1)

# %%
lake_worth_pct.head()
# Out:
#                  pct
# 1996-05-01  0.001672
# 1996-06-01  0.001669
# 1996-07-01  0.003333
# 1996-08-01  0.003322
# 1996-09-01  0.004967

# %%
lake_worth_pct = lake_worth_pct['2013-04':]

# %%
lake_worth_pct.plot();

# %%
from statsmodels.tsa.stattools import adfuller

# %%
adfuller(lake_worth_pct)
# Out:
# (-3.6685402773178515,
#  0.004578065501380513,
#  6,
#  54,
#  {'1%': -3.55770911573439,
#   '5%': -2.9167703434435808,
#   '10%': -2.59622219478738},
#  -442.20977364927535)

# %%
from sklearn.model_selection import TimeSeriesSplit
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
cutoff = '2017-05'
train = lake_worth_pct[:cutoff]
test = lake_worth_pct[cutoff:]

# %%
#Plot_acf is used to identify the q parameter
plot_acf(train);

# %%
plot_pacf(train,method='ywm')

# %%
ar_1 = ARIMA(train, order=(1, 0, 1)).fit()

# We put a typ='levels' to convert our predictions to remove the differencing performed.
train_pred = ar_1.predict()
# Out:
# /Users/johnnahra/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/johnnahra/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/johnnahra/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'

# %%
from sklearn.metrics import mean_squared_error
import numpy as np

np.sqrt(mean_squared_error(train, train_pred))
# Out:
# 0.0040740516947202175

# %%
ar_1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                    pct   No. Observations:                   50
# Model:                 ARIMA(1, 0, 1)   Log Likelihood                 210.242
# Date:                Tue, 28 Mar 2023   AIC                           -412.484
# Time:                        00:56:59   BIC                           -404.836
# Sample:                    04-01-2013   HQIC                          -409.571
#                          - 05-01-2017
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0173      0.003      6.403      0.000       0.012       0.023
# ar.L1          0.6863      0.102      6.734      0.000       0.487       0.886
# ma.L1          0.6950      0.120      5.791      0.000       0.460       0.930
# sigma2      1.247e-05   2.42e-06      5.161      0.000    7.74e-06    1.72e-05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.63   Jarque-Bera (JB):                 2.80
# Prob(Q):                              0.43   Prob(JB):                         0.25
# Heteroskedasticity (H):               0.20   Skew:                             0.51
# Prob(H) (two-sided):                  0.00   Kurtosis:                         3.53
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
y_pred = ar_1.get_forecast(len(test.index))
y_pred_df = y_pred.conf_int(alpha = 0.05) 
y_pred_df["Predictions"] = ar_1.predict(start = y_pred_df.index[0], end = y_pred_df.index[-1])
y_pred_df.index = test.index
y_pred_out = y_pred_df["Predictions"]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(train, color = "black",label='Train')
plt.plot(test, color = "red",label='Test')
plt.ylabel('Monthly % Return')
plt.xlabel('Date')
plt.xticks(rotation=45)
plt.title("Train/Test split for Home Price Monthly Return Data")
plt.plot(y_pred_out, color='green', label = 'Predictions')
plt.legend();

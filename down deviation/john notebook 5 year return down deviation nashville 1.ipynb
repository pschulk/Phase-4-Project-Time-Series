# %%
import pandas as pd

# %%
df = pd.read_csv('../data/zillow_data.csv')

# %%
df.head()
# Out:
#    RegionID  RegionName      City State              Metro CountyName  \
# 0     84654       60657   Chicago    IL            Chicago       Cook
# 1     90668       75070  McKinney    TX  Dallas-Fort Worth     Collin
# 2     91982       77494      Katy    TX            Houston     Harris
# 3     84616       60614   Chicago    IL            Chicago       Cook
# 4     93144       79936   El Paso    TX            El Paso    El Paso
#
#    SizeRank   1996-04   1996-05   1996-06  ...  2017-07  2017-08  2017-09  \
# 0         1  334200.0  335400.0  336500.0  ...  1005500  1007500  1007800
# 1         2  235700.0  236900.0  236700.0  ...   308000   310000   312500
# 2         3  210400.0  212200.0  212200.0  ...   321000   320600   320200
# 3         4  498100.0  500900.0  503100.0  ...  1289800  1287700  1287400
# 4         5   77300.0   77300.0   77300.0  ...   119100   119400   120000
#
#    2017-10  2017-11  2017-12  2018-01  2018-02  2018-03  2018-04
# 0  1009600  1013300  1018700  1024400  1030700  1033800  1030600
# 1   314100   315000   316600   318100   319600   321100   321800
# 2   320400   320800   321200   321200   323000   326900   329900
# 3  1291500  1296600  1299000  1302700  1306400  1308500  1307000
# 4   120300   120300   120300   120300   120500   121000   121500
#
# [5 rows x 272 columns]

# %%
df = df.rename(columns={'RegionName': 'zipcode'})

# %%
df['zipcode'] = df['zipcode'].astype(str).str.zfill(5)

# %%
df['five_year'] = ((df['2018-04']/df['2013-04'])-1)*100

# %%
df.head()
# Out:
#    RegionID zipcode      City State              Metro CountyName  SizeRank  \
# 0     84654   60657   Chicago    IL            Chicago       Cook         1
# 1     90668   75070  McKinney    TX  Dallas-Fort Worth     Collin         2
# 2     91982   77494      Katy    TX            Houston     Harris         3
# 3     84616   60614   Chicago    IL            Chicago       Cook         4
# 4     93144   79936   El Paso    TX            El Paso    El Paso         5
#
#     1996-04   1996-05   1996-06  ...  2017-08  2017-09  2017-10  2017-11  \
# 0  334200.0  335400.0  336500.0  ...  1007500  1007800  1009600  1013300
# 1  235700.0  236900.0  236700.0  ...   310000   312500   314100   315000
# 2  210400.0  212200.0  212200.0  ...   320600   320200   320400   320800
# 3  498100.0  500900.0  503100.0  ...  1287700  1287400  1291500  1296600
# 4   77300.0   77300.0   77300.0  ...   119400   120000   120300   120300
#
#    2017-12  2018-01  2018-02  2018-03  2018-04  five_year
# 0  1018700  1024400  1030700  1033800  1030600  26.082701
# 1   316600   318100   319600   321100   321800  53.384175
# 2   321200   321200   323000   326900   329900  28.315830
# 3  1299000  1302700  1306400  1308500  1307000  25.878840
# 4   120300   120300   120500   121000   121500   7.048458
#
# [5 rows x 273 columns]

# %%
df[['zipcode','City','State','five_year']].sort_values(by=['five_year'],ascending=False).head(20)
# Out:
#      zipcode              City State   five_year
# 7302   80216            Denver    CO  173.872951
# 1477   94601           Oakland    CA  167.943262
# 5830   48240           Redford    MI  161.224490
# 1239   94590           Vallejo    CA  159.379310
# 2661   33705  Saint Petersburg    FL  159.210526
# 6105   37210         Nashville    TN  155.932203
# 2627   33460        Lake Worth    FL  153.647059
# 6563   15201        Pittsburgh    PA  147.593583
# 475    11216          New York    NY  147.591761
# 1835   37207         Nashville    TN  146.683047
# 1461   33461      Palm Springs    FL  146.335404
# 1273   33435     Boynton Beach    FL  144.760820
# 990    33415        Greenacres    FL  144.613435
# 2988   32807           Orlando    FL  144.415243
# 4146   33030         Homestead    FL  144.167610
# 1463   34207         Bradenton    FL  141.495601
# 3794   33056     Miami Gardens    FL  140.647858
# 1681   94606           Oakland    CA  140.110269
# 1758   30316           Atlanta    GA  140.088106
# 1946   85035           Phoenix    AZ  139.940387

# %%
lake_worth = df.loc[df['zipcode'] == '37210']

# %%
lake_worth.head()
# Out:
#       RegionID zipcode       City State      Metro CountyName  SizeRank  \
# 6105     74241   37210  Nashville    TN  Nashville   Davidson      6106
#
#       1996-04  1996-05  1996-06  ...  2017-08  2017-09  2017-10  2017-11  \
# 6105  60800.0  61000.0  61200.0  ...   204600   207700   211100   214500
#
#       2017-12  2018-01  2018-02  2018-03  2018-04   five_year
# 6105   217200   219300   221500   224300   226500  155.932203
#
# [1 rows x 273 columns]

# %%
lake_worth = lake_worth.iloc[:,7:-1]

# %%
lake_worth.head()
# Out:
#       1996-04  1996-05  1996-06  1996-07  1996-08  1996-09  1996-10  1996-11  \
# 6105  60800.0  61000.0  61200.0  61300.0  61500.0  61700.0  61900.0  62100.0
#
#       1996-12  1997-01  ...  2017-07  2017-08  2017-09  2017-10  2017-11  \
# 6105  62400.0  62700.0  ...   201200   204600   207700   211100   214500
#
#       2017-12  2018-01  2018-02  2018-03  2018-04
# 6105   217200   219300   221500   224300   226500
#
# [1 rows x 265 columns]

# %%
lake_worth = lake_worth.T

# %%
lake_worth.head()
# Out:
#             6105
# 1996-04  60800.0
# 1996-05  61000.0
# 1996-06  61200.0
# 1996-07  61300.0
# 1996-08  61500.0

# %%
type(lake_worth)
# Out:
# pandas.core.frame.DataFrame

# %%
lake_worth = lake_worth.rename(columns={6105:'home price'})

# %%
lake_worth.head()
# Out:
#          home price
# 1996-04     60800.0
# 1996-05     61000.0
# 1996-06     61200.0
# 1996-07     61300.0
# 1996-08     61500.0

# %%
lake_worth.index = lake_worth.index.astype('datetime64[ns]')

# %%
lake_worth.index.dtype
# Out:
# dtype('<M8[ns]')

# %%
lake_worth.plot();

# %%
lake_worth['diff'] = lake_worth.diff()

# %%
lake_worth.head()
# Out:
#             home price   diff
# 1996-04-01     60800.0    NaN
# 1996-05-01     61000.0  200.0
# 1996-06-01     61200.0  200.0
# 1996-07-01     61300.0  100.0
# 1996-08-01     61500.0  200.0

# %%
lake_worth['home price shifted'] = lake_worth['home price'].shift()

# %%
lake_worth.tail()
# Out:
#             home price    diff  home price shifted
# 2017-12-01    217200.0  2700.0            214500.0
# 2018-01-01    219300.0  2100.0            217200.0
# 2018-02-01    221500.0  2200.0            219300.0
# 2018-03-01    224300.0  2800.0            221500.0
# 2018-04-01    226500.0  2200.0            224300.0

# %%
lake_worth['pct'] = lake_worth['diff']/lake_worth['home price shifted']

# %%
lake_worth.head()
# Out:
#             home price   diff  home price shifted       pct
# 1996-04-01     60800.0    NaN                 NaN       NaN
# 1996-05-01     61000.0  200.0             60800.0  0.003289
# 1996-06-01     61200.0  200.0             61000.0  0.003279
# 1996-07-01     61300.0  100.0             61200.0  0.001634
# 1996-08-01     61500.0  200.0             61300.0  0.003263

# %%
lake_worth['5 year shift'] = lake_worth['home price'].shift(60)

# %%
lake_worth.head(61)
# Out:
#             home price   diff  home price shifted       pct  5 year shift
# 1996-04-01     60800.0    NaN                 NaN       NaN           NaN
# 1996-05-01     61000.0  200.0             60800.0  0.003289           NaN
# 1996-06-01     61200.0  200.0             61000.0  0.003279           NaN
# 1996-07-01     61300.0  100.0             61200.0  0.001634           NaN
# 1996-08-01     61500.0  200.0             61300.0  0.003263           NaN
# ...                ...    ...                 ...       ...           ...
# 2000-12-01     77000.0  400.0             76600.0  0.005222           NaN
# 2001-01-01     77300.0  300.0             77000.0  0.003896           NaN
# 2001-02-01     77600.0  300.0             77300.0  0.003881           NaN
# 2001-03-01     78000.0  400.0             77600.0  0.005155           NaN
# 2001-04-01     78300.0  300.0             78000.0  0.003846       60800.0
#
# [61 rows x 5 columns]

# %%
lake_worth['5 year return'] = ((lake_worth['home price']/lake_worth['5 year shift'])-1)*100

# %%
lake_worth.tail()
# Out:
#             home price    diff  home price shifted       pct  5 year shift  \
# 2017-12-01    217200.0  2700.0            214500.0  0.012587       83500.0
# 2018-01-01    219300.0  2100.0            217200.0  0.009669       84600.0
# 2018-02-01    221500.0  2200.0            219300.0  0.010032       85600.0
# 2018-03-01    224300.0  2800.0            221500.0  0.012641       86800.0
# 2018-04-01    226500.0  2200.0            224300.0  0.009808       88500.0
#
#             5 year return
# 2017-12-01     160.119760
# 2018-01-01     159.219858
# 2018-02-01     158.761682
# 2018-03-01     158.410138
# 2018-04-01     155.932203

# %%
lake_worth.head()
# Out:
#             home price   diff  home price shifted       pct  5 year shift  \
# 1996-04-01     60800.0    NaN                 NaN       NaN           NaN
# 1996-05-01     61000.0  200.0             60800.0  0.003289           NaN
# 1996-06-01     61200.0  200.0             61000.0  0.003279           NaN
# 1996-07-01     61300.0  100.0             61200.0  0.001634           NaN
# 1996-08-01     61500.0  200.0             61300.0  0.003263           NaN
#
#             5 year return
# 1996-04-01            NaN
# 1996-05-01            NaN
# 1996-06-01            NaN
# 1996-07-01            NaN
# 1996-08-01            NaN

# %%
lw_dvar = lake_worth.dropna()

# %%
df_mean = pd.read_csv('../data/national.csv')

# %%
df_mean.head()
# Out:
#           Unnamed: 0          0
# 0  five-year 2001-04  35.180540
# 1  five-year 2001-05  35.760117
# 2  five-year 2001-06  36.308179
# 3  five-year 2001-07  36.831948
# 4  five-year 2001-08  37.328660

# %%
df_mean.iloc[:,1].values
# Out:
# array([ 35.18053985,  35.76011692,  36.30817887,  36.83194827,
#         37.32865988,  37.8069953 ,  38.27221538,  38.73249943,
#         39.111278  ,  39.4460225 ,  39.83724063,  40.30037615,
#         40.72237946,  41.09422992,  41.43360942,  41.74907935,
#         42.04327701,  42.33381627,  42.59648697,  42.99951262,
#         43.39240939,  43.57326369,  43.62538032,  43.80738873,
#         44.01288126,  44.2614003 ,  44.57818087,  44.96467443,
#         45.38097162,  45.81328425,  46.21790364,  46.55667771,
#         46.75474477,  46.89544351,  47.13687621,  47.55439538,
#         48.08249299,  48.73351988,  49.51166504,  50.37375685,
#         51.24110653,  52.09484394,  52.88972001,  53.56845997,
#         54.0826896 ,  54.45101928,  54.77126623,  55.19703608,
#         55.72187368,  56.2947537 ,  56.91857375,  57.56652767,
#         58.15227369,  58.64489454,  58.99356943,  59.1596511 ,
#         59.11005283,  58.88426206,  58.55733692,  58.27644121,
#         58.01882505,  57.71987763,  57.34617398,  56.88177713,
#         56.28417717,  55.57493772,  54.74936412,  53.81686734,
#         52.83386906,  51.82329395,  50.73004778,  49.64242487,
#         48.56133131,  47.41535353,  46.17818837,  44.8967385 ,
#         43.55008563,  42.14554825,  40.68452462,  38.98826574,
#         37.13337659,  35.36919665,  33.67675816,  31.94448508,
#         30.17153582,  28.30469114,  26.32317685,  24.35189182,
#         22.43994641,  20.61612751,  18.87062426,  17.23859908,
#         15.72086628,  14.27883333,  12.78158169,  11.21612255,
#          9.55901455,   7.75626154,   5.90028062,   4.22381977,
#          2.75547556,   1.42573653,   0.20809769,  -0.85699026,
#         -1.81818966,  -2.70467547,  -3.37057566,  -4.23776625,
#         -5.37623841,  -6.38381087,  -7.19705591,  -8.21339982,
#         -9.3242649 , -10.44320118, -11.52275308, -12.56952694,
#        -13.5849791 , -14.52927597, -15.40908083, -16.21922779,
#        -16.92841743, -17.54888875, -18.1221116 , -18.60464081,
#        -18.99311301, -19.31376722, -19.58035029, -19.79378559,
#        -19.98020123, -20.15545673, -20.28153773, -20.29927883,
#        -20.1848498 , -19.95184429, -19.65582478, -19.32095233,
#        -18.95251034, -18.54447235, -18.08623817, -17.54050802,
#        -16.93178614, -16.29044071, -15.56093517, -14.7097567 ,
#        -13.74038068, -12.66169059, -11.48235149, -10.28820384,
#         -9.1499555 ,  -8.10912986,  -7.12673341,  -6.17631668,
#         -5.27705022,  -4.41703672,  -3.50970341,  -2.53625053,
#         -1.45698488,  -0.19854905,   1.11734141,   2.25009727,
#          3.13422916,   3.82499829,   4.39973588,   4.90160896,
#          5.33868265,   5.75351672,   6.01471595,   6.52398799,
#          7.39171167,   8.21684445,   8.81505649,   9.66265571,
#         10.66644064,  11.72729217,  12.7903877 ,  13.90373299,
#         15.0972819 ,  16.36266533,  17.61098535,  18.76314629,
#         19.87733755,  21.05261618,  22.29716737,  23.51015826,
#         24.62820998,  25.65042234,  26.63819342,  27.60527726,
#         28.50614653,  29.40427079,  30.23923857,  30.86539096,
#         31.33546649,  31.78915127,  32.18735   ,  32.53072575,
#         32.90503973,  33.28267069,  33.5877789 ,  33.78443833,
#         33.98138802,  34.14608058,  34.38170443,  34.75969992,
#         34.75328789])

# %%
lw_dvar['mar'] = df_mean.iloc[:,1].values
# Out:
# <ipython-input-36-27c190f2f8ee>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lw_dvar['mar'] = df_mean.iloc[:,1].values

# %%
lw_dvar.tail()
# Out:
#             home price    diff  home price shifted       pct  5 year shift  \
# 2017-12-01    217200.0  2700.0            214500.0  0.012587       83500.0
# 2018-01-01    219300.0  2100.0            217200.0  0.009669       84600.0
# 2018-02-01    221500.0  2200.0            219300.0  0.010032       85600.0
# 2018-03-01    224300.0  2800.0            221500.0  0.012641       86800.0
# 2018-04-01    226500.0  2200.0            224300.0  0.009808       88500.0
#
#             5 year return        mar
# 2017-12-01     160.119760  33.981388
# 2018-01-01     159.219858  34.146081
# 2018-02-01     158.761682  34.381704
# 2018-03-01     158.410138  34.759700
# 2018-04-01     155.932203  34.753288

# %%
lw_dvar['5 year minus mar'] = lw_dvar['5 year return'] - lw_dvar['mar']
# Out:
# <ipython-input-38-0dfe89c527e9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lw_dvar['5 year minus mar'] = lw_dvar['5 year return'] - lw_dvar['mar']

# %%
lw_dvar.head()
# Out:
#             home price   diff  home price shifted       pct  5 year shift  \
# 2001-04-01     78300.0  300.0             78000.0  0.003846       60800.0
# 2001-05-01     78500.0  200.0             78300.0  0.002554       61000.0
# 2001-06-01     78800.0  300.0             78500.0  0.003822       61200.0
# 2001-07-01     79000.0  200.0             78800.0  0.002538       61300.0
# 2001-08-01     79200.0  200.0             79000.0  0.002532       61500.0
#
#             5 year return        mar  5 year minus mar
# 2001-04-01      28.782895  35.180540         -6.397645
# 2001-05-01      28.688525  35.760117         -7.071592
# 2001-06-01      28.758170  36.308179         -7.550009
# 2001-07-01      28.874388  36.831948         -7.957560
# 2001-08-01      28.780488  37.328660         -8.548172

# %%
lw_dvar['5 year minus mar'].plot();

# %%
lw_down = lw_dvar.loc[lw_dvar['5 year minus mar'] < 0]

# %%
lw_down['neg sq'] = lw_down['5 year minus mar']**2
# Out:
# <ipython-input-42-0c89c2b59d50>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lw_down['neg sq'] = lw_down['5 year minus mar']**2

# %%
lw_down.head(60)
# Out:
#             home price    diff  home price shifted       pct  5 year shift  \
# 2001-04-01     78300.0   300.0             78000.0  0.003846       60800.0
# 2001-05-01     78500.0   200.0             78300.0  0.002554       61000.0
# 2001-06-01     78800.0   300.0             78500.0  0.003822       61200.0
# 2001-07-01     79000.0   200.0             78800.0  0.002538       61300.0
# 2001-08-01     79200.0   200.0             79000.0  0.002532       61500.0
# 2001-09-01     79400.0   200.0             79200.0  0.002525       61700.0
# 2001-10-01     79700.0   300.0             79400.0  0.003778       61900.0
# 2001-11-01     80000.0   300.0             79700.0  0.003764       62100.0
# 2001-12-01     80300.0   300.0             80000.0  0.003750       62400.0
# 2002-01-01     80500.0   200.0             80300.0  0.002491       62700.0
# 2002-02-01     80700.0   200.0             80500.0  0.002484       62900.0
# 2002-03-01     80900.0   200.0             80700.0  0.002478       63200.0
# 2002-04-01     81000.0   100.0             80900.0  0.001236       63400.0
# 2002-05-01     81000.0     0.0             81000.0  0.000000       63700.0
# 2002-06-01     81100.0   100.0             81000.0  0.001235       63900.0
# 2002-07-01     81100.0     0.0             81100.0  0.000000       64100.0
# 2002-08-01     81100.0     0.0             81100.0  0.000000       64400.0
# 2002-09-01     81100.0     0.0             81100.0  0.000000       64700.0
# 2002-10-01     81100.0     0.0             81100.0  0.000000       65000.0
# 2002-11-01     81000.0  -100.0             81100.0 -0.001233       65300.0
# 2002-12-01     80800.0  -200.0             81000.0 -0.002469       65600.0
# 2003-01-01     80900.0   100.0             80800.0  0.001238       66000.0
# 2003-02-01     81000.0   100.0             80900.0  0.001236       66300.0
# 2003-03-01     81100.0   100.0             81000.0  0.001235       66600.0
# 2003-04-01     81200.0   100.0             81100.0  0.001233       66900.0
# 2003-05-01     81200.0     0.0             81200.0  0.000000       67200.0
# 2003-06-01     81300.0   100.0             81200.0  0.001232       67500.0
# 2003-07-01     81300.0     0.0             81300.0  0.000000       67700.0
# 2003-08-01     81500.0   200.0             81300.0  0.002460       68000.0
# 2003-09-01     81600.0   100.0             81500.0  0.001227       68300.0
# 2003-10-01     81800.0   200.0             81600.0  0.002451       68600.0
# 2003-11-01     82000.0   200.0             81800.0  0.002445       68900.0
# 2003-12-01     82300.0   300.0             82000.0  0.003659       69200.0
# 2004-01-01     82500.0   200.0             82300.0  0.002430       69600.0
# 2004-02-01     82800.0   300.0             82500.0  0.003636       69900.0
# 2004-03-01     83100.0   300.0             82800.0  0.003623       70200.0
# 2004-04-01     83500.0   400.0             83100.0  0.004813       70500.0
# 2004-05-01     83800.0   300.0             83500.0  0.003593       70800.0
# 2004-06-01     84100.0   300.0             83800.0  0.003580       71100.0
# 2004-07-01     84400.0   300.0             84100.0  0.003567       71400.0
# 2004-08-01     84700.0   300.0             84400.0  0.003555       71700.0
# 2004-09-01     85000.0   300.0             84700.0  0.003542       72000.0
# 2004-10-01     85300.0   300.0             85000.0  0.003529       72300.0
# 2004-11-01     85700.0   400.0             85300.0  0.004689       72700.0
# 2004-12-01     86200.0   500.0             85700.0  0.005834       73100.0
# 2005-01-01     86600.0   400.0             86200.0  0.004640       73500.0
# 2005-02-01     86900.0   300.0             86600.0  0.003464       73900.0
# 2005-03-01     87200.0   300.0             86900.0  0.003452       74200.0
# 2005-04-01     87500.0   300.0             87200.0  0.003440       74600.0
# 2005-05-01     88000.0   500.0             87500.0  0.005714       74900.0
# 2005-06-01     88700.0   700.0             88000.0  0.007955       75200.0
# 2005-07-01     89500.0   800.0             88700.0  0.009019       75400.0
# 2005-08-01     90500.0  1000.0             89500.0  0.011173       75700.0
# 2005-09-01     91500.0  1000.0             90500.0  0.011050       75900.0
# 2005-10-01     92200.0   700.0             91500.0  0.007650       76200.0
# 2005-11-01     92800.0   600.0             92200.0  0.006508       76600.0
# 2005-12-01     93300.0   500.0             92800.0  0.005388       77000.0
# 2006-01-01     93800.0   500.0             93300.0  0.005359       77300.0
# 2006-02-01     94400.0   600.0             93800.0  0.006397       77600.0
# 2006-03-01     95400.0  1000.0             94400.0  0.010593       78000.0
#
#             5 year return        mar  5 year minus mar       neg sq
# 2001-04-01      28.782895  35.180540         -6.397645    40.929863
# 2001-05-01      28.688525  35.760117         -7.071592    50.007418
# 2001-06-01      28.758170  36.308179         -7.550009    57.002635
# 2001-07-01      28.874388  36.831948         -7.957560    63.322761
# 2001-08-01      28.780488  37.328660         -8.548172    73.071246
# 2001-09-01      28.687196  37.806995         -9.119799    83.170737
# 2001-10-01      28.756058  38.272215         -9.516157    90.557248
# 2001-11-01      28.824477  38.732499         -9.908023    98.168915
# 2001-12-01      28.685897  39.111278        -10.425381   108.688560
# 2002-01-01      28.389155  39.446022        -11.056868   122.254325
# 2002-02-01      28.298887  39.837241        -11.538354   133.133602
# 2002-03-01      28.006329  40.300376        -12.294047   151.143592
# 2002-04-01      27.760252  40.722379        -12.962127   168.016739
# 2002-05-01      27.158556  41.094230        -13.935674   194.203015
# 2002-06-01      26.917058  41.433609        -14.516552   210.730268
# 2002-07-01      26.521061  41.749079        -15.228019   231.892548
# 2002-08-01      25.931677  42.043277        -16.111600   259.583654
# 2002-09-01      25.347759  42.333816        -16.986057   288.526146
# 2002-10-01      24.769231  42.596487        -17.827256   317.811064
# 2002-11-01      24.042879  42.999513        -18.956634   359.353957
# 2002-12-01      23.170732  43.392409        -20.221678   408.916248
# 2003-01-01      22.575758  43.573264        -20.997506   440.895263
# 2003-02-01      22.171946  43.625380        -21.453435   460.249857
# 2003-03-01      21.771772  43.807389        -22.035617   485.568415
# 2003-04-01      21.375187  44.012881        -22.637694   512.465208
# 2003-05-01      20.833333  44.261400        -23.428067   548.874322
# 2003-06-01      20.444444  44.578181        -24.133736   582.437234
# 2003-07-01      20.088626  44.964674        -24.876048   618.817771
# 2003-08-01      19.852941  45.380972        -25.528030   651.680338
# 2003-09-01      19.472914  45.813284        -26.340371   693.815125
# 2003-10-01      19.241983  46.217904        -26.975921   727.700321
# 2003-11-01      19.013062  46.556678        -27.543615   758.650744
# 2003-12-01      18.930636  46.754745        -27.824109   774.181038
# 2004-01-01      18.534483  46.895444        -28.360961   804.344095
# 2004-02-01      18.454936  47.136876        -28.681941   822.653716
# 2004-03-01      18.376068  47.554395        -29.178327   851.374767
# 2004-04-01      18.439716  48.082493        -29.642777   878.694209
# 2004-05-01      18.361582  48.733520        -30.371938   922.454615
# 2004-06-01      18.284107  49.511665        -31.227558   975.160388
# 2004-07-01      18.207283  50.373757        -32.166474  1034.682045
# 2004-08-01      18.131102  51.241107        -33.110005  1096.272413
# 2004-09-01      18.055556  52.094844        -34.039288  1158.673153
# 2004-10-01      17.980636  52.889720        -34.909084  1218.644130
# 2004-11-01      17.881706  53.568460        -35.686754  1273.544434
# 2004-12-01      17.920657  54.082690        -36.162033  1307.692628
# 2005-01-01      17.823129  54.451019        -36.627890  1341.602328
# 2005-02-01      17.591340  54.771266        -37.179927  1382.346941
# 2005-03-01      17.520216  55.197036        -37.676820  1419.542799
# 2005-04-01      17.292225  55.721874        -38.429648  1476.837882
# 2005-05-01      17.489987  56.294754        -38.804767  1505.809946
# 2005-06-01      17.952128  56.918574        -38.966446  1518.383921
# 2005-07-01      18.700265  57.566528        -38.866262  1510.586354
# 2005-08-01      19.550859  58.152274        -38.601415  1490.069243
# 2005-09-01      20.553360  58.644895        -38.091535  1450.965028
# 2005-10-01      20.997375  58.993569        -37.996194  1443.710767
# 2005-11-01      21.148825  59.159651        -38.010826  1444.822896
# 2005-12-01      21.168831  59.110053        -37.941222  1439.536301
# 2006-01-01      21.345408  58.884262        -37.538855  1409.165601
# 2006-02-01      21.649485  58.557337        -36.907852  1362.189568
# 2006-03-01      22.307692  58.276441        -35.968749  1293.750897

# %%
lw_down.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 106 entries, 2001-04-01 to 2013-05-01
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   home price          106 non-null    float64
#  1   diff                106 non-null    float64
#  2   home price shifted  106 non-null    float64
#  3   pct                 106 non-null    float64
#  4   5 year shift        106 non-null    float64
#  5   5 year return       106 non-null    float64
#  6   mar                 106 non-null    float64
#  7   5 year minus mar    106 non-null    float64
#  8   neg sq              106 non-null    float64
# dtypes: float64(9)
# memory usage: 8.3 KB

# %%
import numpy as np

np.sqrt(lw_down['neg sq'].sum()/lw_dvar['mar'].count())
# Out:
# 16.457042623270837

# %%
lw_var = lake_worth['5 year return'].dropna()

# %%
lw_var.std()
# Out:
# 85.07622645166362

# %%
lw_var.mean()
# Out:
# 54.0368829557541

# %%
lw_var.describe()
# Out:
# count    206.000000
# mean      53.871655
# std       84.901596
# min      -71.832123
# 25%      -33.036036
# 50%       57.167779
# 75%      124.909945
# max      192.718999
# Name: 5 year return, dtype: float64

# %%
lw_var.plot();

# %%
lake_worth = lake_worth.dropna()

# %%
lake_worth.head()
# Out:
#             home price   diff  home price shifted       pct
# 1996-05-01     59900.0  100.0             59800.0  0.001672
# 1996-06-01     60000.0  100.0             59900.0  0.001669
# 1996-07-01     60200.0  200.0             60000.0  0.003333
# 1996-08-01     60400.0  200.0             60200.0  0.003322
# 1996-09-01     60700.0  300.0             60400.0  0.004967

# %%
lake_worth_pct = lake_worth.drop(['home price','diff','home price shifted'],axis=1)

# %%
lake_worth_pct.head()
# Out:
#                  pct
# 1996-05-01  0.001672
# 1996-06-01  0.001669
# 1996-07-01  0.003333
# 1996-08-01  0.003322
# 1996-09-01  0.004967

# %%
lake_worth_pct = lake_worth_pct['2013-04':]

# %%
lake_worth_pct.plot();

# %%
from statsmodels.tsa.stattools import adfuller

# %%
adfuller(lake_worth_pct)
# Out:
# (-3.6685402773178515,
#  0.004578065501380513,
#  6,
#  54,
#  {'1%': -3.55770911573439,
#   '5%': -2.9167703434435808,
#   '10%': -2.59622219478738},
#  -442.20977364927535)

# %%
from sklearn.model_selection import TimeSeriesSplit
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
cutoff = '2017-05'
train = lake_worth_pct[:cutoff]
test = lake_worth_pct[cutoff:]

# %%
#Plot_acf is used to identify the q parameter
plot_acf(train);

# %%
plot_pacf(train,method='ywm')

# %%
ar_1 = ARIMA(train, order=(1, 0, 1)).fit()

# We put a typ='levels' to convert our predictions to remove the differencing performed.
train_pred = ar_1.predict()
# Out:
# /Users/johnnahra/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/johnnahra/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/johnnahra/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'

# %%
from sklearn.metrics import mean_squared_error
import numpy as np

np.sqrt(mean_squared_error(train, train_pred))
# Out:
# 0.0040740516947202175

# %%
ar_1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                    pct   No. Observations:                   50
# Model:                 ARIMA(1, 0, 1)   Log Likelihood                 210.242
# Date:                Tue, 28 Mar 2023   AIC                           -412.484
# Time:                        00:56:59   BIC                           -404.836
# Sample:                    04-01-2013   HQIC                          -409.571
#                          - 05-01-2017
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0173      0.003      6.403      0.000       0.012       0.023
# ar.L1          0.6863      0.102      6.734      0.000       0.487       0.886
# ma.L1          0.6950      0.120      5.791      0.000       0.460       0.930
# sigma2      1.247e-05   2.42e-06      5.161      0.000    7.74e-06    1.72e-05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.63   Jarque-Bera (JB):                 2.80
# Prob(Q):                              0.43   Prob(JB):                         0.25
# Heteroskedasticity (H):               0.20   Skew:                             0.51
# Prob(H) (two-sided):                  0.00   Kurtosis:                         3.53
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
y_pred = ar_1.get_forecast(len(test.index))
y_pred_df = y_pred.conf_int(alpha = 0.05) 
y_pred_df["Predictions"] = ar_1.predict(start = y_pred_df.index[0], end = y_pred_df.index[-1])
y_pred_df.index = test.index
y_pred_out = y_pred_df["Predictions"]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(train, color = "black",label='Train')
plt.plot(test, color = "red",label='Test')
plt.ylabel('Monthly % Return')
plt.xlabel('Date')
plt.xticks(rotation=45)
plt.title("Train/Test split for Home Price Monthly Return Data")
plt.plot(y_pred_out, color='green', label = 'Predictions')
plt.legend();

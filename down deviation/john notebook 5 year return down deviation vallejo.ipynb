# %%
import pandas as pd

# %%
df = pd.read_csv('../data/zillow_data.csv')

# %%
df.head()
# Out:
#    RegionID  RegionName      City State              Metro CountyName  \
# 0     84654       60657   Chicago    IL            Chicago       Cook
# 1     90668       75070  McKinney    TX  Dallas-Fort Worth     Collin
# 2     91982       77494      Katy    TX            Houston     Harris
# 3     84616       60614   Chicago    IL            Chicago       Cook
# 4     93144       79936   El Paso    TX            El Paso    El Paso
#
#    SizeRank   1996-04   1996-05   1996-06  ...  2017-07  2017-08  2017-09  \
# 0         1  334200.0  335400.0  336500.0  ...  1005500  1007500  1007800
# 1         2  235700.0  236900.0  236700.0  ...   308000   310000   312500
# 2         3  210400.0  212200.0  212200.0  ...   321000   320600   320200
# 3         4  498100.0  500900.0  503100.0  ...  1289800  1287700  1287400
# 4         5   77300.0   77300.0   77300.0  ...   119100   119400   120000
#
#    2017-10  2017-11  2017-12  2018-01  2018-02  2018-03  2018-04
# 0  1009600  1013300  1018700  1024400  1030700  1033800  1030600
# 1   314100   315000   316600   318100   319600   321100   321800
# 2   320400   320800   321200   321200   323000   326900   329900
# 3  1291500  1296600  1299000  1302700  1306400  1308500  1307000
# 4   120300   120300   120300   120300   120500   121000   121500
#
# [5 rows x 272 columns]

# %%
df = df.rename(columns={'RegionName': 'zipcode'})

# %%
df['zipcode'] = df['zipcode'].astype(str).str.zfill(5)

# %%
df['five_year'] = ((df['2018-04']/df['2013-04'])-1)*100

# %%
df.head()
# Out:
#    RegionID zipcode      City State              Metro CountyName  SizeRank  \
# 0     84654   60657   Chicago    IL            Chicago       Cook         1
# 1     90668   75070  McKinney    TX  Dallas-Fort Worth     Collin         2
# 2     91982   77494      Katy    TX            Houston     Harris         3
# 3     84616   60614   Chicago    IL            Chicago       Cook         4
# 4     93144   79936   El Paso    TX            El Paso    El Paso         5
#
#     1996-04   1996-05   1996-06  ...  2017-08  2017-09  2017-10  2017-11  \
# 0  334200.0  335400.0  336500.0  ...  1007500  1007800  1009600  1013300
# 1  235700.0  236900.0  236700.0  ...   310000   312500   314100   315000
# 2  210400.0  212200.0  212200.0  ...   320600   320200   320400   320800
# 3  498100.0  500900.0  503100.0  ...  1287700  1287400  1291500  1296600
# 4   77300.0   77300.0   77300.0  ...   119400   120000   120300   120300
#
#    2017-12  2018-01  2018-02  2018-03  2018-04  five_year
# 0  1018700  1024400  1030700  1033800  1030600  26.082701
# 1   316600   318100   319600   321100   321800  53.384175
# 2   321200   321200   323000   326900   329900  28.315830
# 3  1299000  1302700  1306400  1308500  1307000  25.878840
# 4   120300   120300   120500   121000   121500   7.048458
#
# [5 rows x 273 columns]

# %%
df[['zipcode','City','State','five_year']].sort_values(by=['five_year'],ascending=False).head(20)
# Out:
#      zipcode              City State   five_year
# 7302   80216            Denver    CO  173.872951
# 1477   94601           Oakland    CA  167.943262
# 5830   48240           Redford    MI  161.224490
# 1239   94590           Vallejo    CA  159.379310
# 2661   33705  Saint Petersburg    FL  159.210526
# 6105   37210         Nashville    TN  155.932203
# 2627   33460        Lake Worth    FL  153.647059
# 6563   15201        Pittsburgh    PA  147.593583
# 475    11216          New York    NY  147.591761
# 1835   37207         Nashville    TN  146.683047
# 1461   33461      Palm Springs    FL  146.335404
# 1273   33435     Boynton Beach    FL  144.760820
# 990    33415        Greenacres    FL  144.613435
# 2988   32807           Orlando    FL  144.415243
# 4146   33030         Homestead    FL  144.167610
# 1463   34207         Bradenton    FL  141.495601
# 3794   33056     Miami Gardens    FL  140.647858
# 1681   94606           Oakland    CA  140.110269
# 1758   30316           Atlanta    GA  140.088106
# 1946   85035           Phoenix    AZ  139.940387

# %%
lake_worth = df.loc[df['zipcode'] == '94590']

# %%
lake_worth.head()
# Out:
#       RegionID zipcode     City State    Metro CountyName  SizeRank   1996-04  \
# 1239     97795   94590  Vallejo    CA  Vallejo     Solano      1240  108200.0
#
#        1996-05   1996-06  ...  2017-08  2017-09  2017-10  2017-11  2017-12  \
# 1239  107800.0  107500.0  ...   339600   343500   346700   351200   357100
#
#       2018-01  2018-02  2018-03  2018-04  five_year
# 1239   362500   366900   371600   376100  159.37931
#
# [1 rows x 273 columns]

# %%
lake_worth = lake_worth.iloc[:,7:-1]

# %%
lake_worth.head()
# Out:
#        1996-04   1996-05   1996-06   1996-07   1996-08   1996-09   1996-10  \
# 1239  108200.0  107800.0  107500.0  107300.0  107100.0  106900.0  106800.0
#
#        1996-11   1996-12   1997-01  ...  2017-07  2017-08  2017-09  2017-10  \
# 1239  106500.0  106400.0  106300.0  ...   335100   339600   343500   346700
#
#       2017-11  2017-12  2018-01  2018-02  2018-03  2018-04
# 1239   351200   357100   362500   366900   371600   376100
#
# [1 rows x 265 columns]

# %%
lake_worth = lake_worth.T

# %%
lake_worth.head()
# Out:
#              1239
# 1996-04  108200.0
# 1996-05  107800.0
# 1996-06  107500.0
# 1996-07  107300.0
# 1996-08  107100.0

# %%
type(lake_worth)
# Out:
# pandas.core.frame.DataFrame

# %%
lake_worth = lake_worth.rename(columns={1239:'home price'})

# %%
lake_worth.head()
# Out:
#          home price
# 1996-04    108200.0
# 1996-05    107800.0
# 1996-06    107500.0
# 1996-07    107300.0
# 1996-08    107100.0

# %%
lake_worth.index = lake_worth.index.astype('datetime64[ns]')

# %%
lake_worth.index.dtype
# Out:
# dtype('<M8[ns]')

# %%
lake_worth.plot();

# %%
lake_worth['diff'] = lake_worth.diff()

# %%
lake_worth.head()
# Out:
#             home price   diff
# 1996-04-01    108200.0    NaN
# 1996-05-01    107800.0 -400.0
# 1996-06-01    107500.0 -300.0
# 1996-07-01    107300.0 -200.0
# 1996-08-01    107100.0 -200.0

# %%
lake_worth['home price shifted'] = lake_worth['home price'].shift()

# %%
lake_worth.tail()
# Out:
#             home price    diff  home price shifted
# 2017-12-01    357100.0  5900.0            351200.0
# 2018-01-01    362500.0  5400.0            357100.0
# 2018-02-01    366900.0  4400.0            362500.0
# 2018-03-01    371600.0  4700.0            366900.0
# 2018-04-01    376100.0  4500.0            371600.0

# %%
lake_worth['pct'] = lake_worth['diff']/lake_worth['home price shifted']

# %%
lake_worth.head()
# Out:
#             home price   diff  home price shifted       pct
# 1996-04-01    108200.0    NaN                 NaN       NaN
# 1996-05-01    107800.0 -400.0            108200.0 -0.003697
# 1996-06-01    107500.0 -300.0            107800.0 -0.002783
# 1996-07-01    107300.0 -200.0            107500.0 -0.001860
# 1996-08-01    107100.0 -200.0            107300.0 -0.001864

# %%
lake_worth['5 year shift'] = lake_worth['home price'].shift(60)

# %%
lake_worth.head(61)
# Out:
#             home price    diff  home price shifted       pct  5 year shift
# 1996-04-01    108200.0     NaN                 NaN       NaN           NaN
# 1996-05-01    107800.0  -400.0            108200.0 -0.003697           NaN
# 1996-06-01    107500.0  -300.0            107800.0 -0.002783           NaN
# 1996-07-01    107300.0  -200.0            107500.0 -0.001860           NaN
# 1996-08-01    107100.0  -200.0            107300.0 -0.001864           NaN
# ...                ...     ...                 ...       ...           ...
# 2000-12-01    173900.0  3800.0            170100.0  0.022340           NaN
# 2001-01-01    177800.0  3900.0            173900.0  0.022427           NaN
# 2001-02-01    181600.0  3800.0            177800.0  0.021372           NaN
# 2001-03-01    185400.0  3800.0            181600.0  0.020925           NaN
# 2001-04-01    189200.0  3800.0            185400.0  0.020496      108200.0
#
# [61 rows x 5 columns]

# %%
lake_worth['5 year return'] = ((lake_worth['home price']/lake_worth['5 year shift'])-1)*100

# %%
lake_worth.tail()
# Out:
#             home price    diff  home price shifted       pct  5 year shift  \
# 2017-12-01    357100.0  5900.0            351200.0  0.016800      131800.0
# 2018-01-01    362500.0  5400.0            357100.0  0.015122      135100.0
# 2018-02-01    366900.0  4400.0            362500.0  0.012138      139000.0
# 2018-03-01    371600.0  4700.0            366900.0  0.012810      142100.0
# 2018-04-01    376100.0  4500.0            371600.0  0.012110      145000.0
#
#             5 year return
# 2017-12-01     170.940819
# 2018-01-01     168.319763
# 2018-02-01     163.956835
# 2018-03-01     161.505982
# 2018-04-01     159.379310

# %%
lake_worth.head()
# Out:
#             home price   diff  home price shifted       pct  5 year shift  \
# 1996-04-01    108200.0    NaN                 NaN       NaN           NaN
# 1996-05-01    107800.0 -400.0            108200.0 -0.003697           NaN
# 1996-06-01    107500.0 -300.0            107800.0 -0.002783           NaN
# 1996-07-01    107300.0 -200.0            107500.0 -0.001860           NaN
# 1996-08-01    107100.0 -200.0            107300.0 -0.001864           NaN
#
#             5 year return
# 1996-04-01            NaN
# 1996-05-01            NaN
# 1996-06-01            NaN
# 1996-07-01            NaN
# 1996-08-01            NaN

# %%
lw_dvar = lake_worth.dropna()

# %%
df_mean = pd.read_csv('../data/national.csv')

# %%
df_mean.head()
# Out:
#           Unnamed: 0          0
# 0  five-year 2001-04  35.180540
# 1  five-year 2001-05  35.760117
# 2  five-year 2001-06  36.308179
# 3  five-year 2001-07  36.831948
# 4  five-year 2001-08  37.328660

# %%
df_mean.iloc[:,1].values
# Out:
# array([ 35.18053985,  35.76011692,  36.30817887,  36.83194827,
#         37.32865988,  37.8069953 ,  38.27221538,  38.73249943,
#         39.111278  ,  39.4460225 ,  39.83724063,  40.30037615,
#         40.72237946,  41.09422992,  41.43360942,  41.74907935,
#         42.04327701,  42.33381627,  42.59648697,  42.99951262,
#         43.39240939,  43.57326369,  43.62538032,  43.80738873,
#         44.01288126,  44.2614003 ,  44.57818087,  44.96467443,
#         45.38097162,  45.81328425,  46.21790364,  46.55667771,
#         46.75474477,  46.89544351,  47.13687621,  47.55439538,
#         48.08249299,  48.73351988,  49.51166504,  50.37375685,
#         51.24110653,  52.09484394,  52.88972001,  53.56845997,
#         54.0826896 ,  54.45101928,  54.77126623,  55.19703608,
#         55.72187368,  56.2947537 ,  56.91857375,  57.56652767,
#         58.15227369,  58.64489454,  58.99356943,  59.1596511 ,
#         59.11005283,  58.88426206,  58.55733692,  58.27644121,
#         58.01882505,  57.71987763,  57.34617398,  56.88177713,
#         56.28417717,  55.57493772,  54.74936412,  53.81686734,
#         52.83386906,  51.82329395,  50.73004778,  49.64242487,
#         48.56133131,  47.41535353,  46.17818837,  44.8967385 ,
#         43.55008563,  42.14554825,  40.68452462,  38.98826574,
#         37.13337659,  35.36919665,  33.67675816,  31.94448508,
#         30.17153582,  28.30469114,  26.32317685,  24.35189182,
#         22.43994641,  20.61612751,  18.87062426,  17.23859908,
#         15.72086628,  14.27883333,  12.78158169,  11.21612255,
#          9.55901455,   7.75626154,   5.90028062,   4.22381977,
#          2.75547556,   1.42573653,   0.20809769,  -0.85699026,
#         -1.81818966,  -2.70467547,  -3.37057566,  -4.23776625,
#         -5.37623841,  -6.38381087,  -7.19705591,  -8.21339982,
#         -9.3242649 , -10.44320118, -11.52275308, -12.56952694,
#        -13.5849791 , -14.52927597, -15.40908083, -16.21922779,
#        -16.92841743, -17.54888875, -18.1221116 , -18.60464081,
#        -18.99311301, -19.31376722, -19.58035029, -19.79378559,
#        -19.98020123, -20.15545673, -20.28153773, -20.29927883,
#        -20.1848498 , -19.95184429, -19.65582478, -19.32095233,
#        -18.95251034, -18.54447235, -18.08623817, -17.54050802,
#        -16.93178614, -16.29044071, -15.56093517, -14.7097567 ,
#        -13.74038068, -12.66169059, -11.48235149, -10.28820384,
#         -9.1499555 ,  -8.10912986,  -7.12673341,  -6.17631668,
#         -5.27705022,  -4.41703672,  -3.50970341,  -2.53625053,
#         -1.45698488,  -0.19854905,   1.11734141,   2.25009727,
#          3.13422916,   3.82499829,   4.39973588,   4.90160896,
#          5.33868265,   5.75351672,   6.01471595,   6.52398799,
#          7.39171167,   8.21684445,   8.81505649,   9.66265571,
#         10.66644064,  11.72729217,  12.7903877 ,  13.90373299,
#         15.0972819 ,  16.36266533,  17.61098535,  18.76314629,
#         19.87733755,  21.05261618,  22.29716737,  23.51015826,
#         24.62820998,  25.65042234,  26.63819342,  27.60527726,
#         28.50614653,  29.40427079,  30.23923857,  30.86539096,
#         31.33546649,  31.78915127,  32.18735   ,  32.53072575,
#         32.90503973,  33.28267069,  33.5877789 ,  33.78443833,
#         33.98138802,  34.14608058,  34.38170443,  34.75969992,
#         34.75328789])

# %%
lw_dvar['mar'] = df_mean.iloc[:,1].values
# Out:
# <ipython-input-36-27c190f2f8ee>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lw_dvar['mar'] = df_mean.iloc[:,1].values

# %%
lw_dvar.tail()
# Out:
#             home price    diff  home price shifted       pct  5 year shift  \
# 2017-12-01    357100.0  5900.0            351200.0  0.016800      131800.0
# 2018-01-01    362500.0  5400.0            357100.0  0.015122      135100.0
# 2018-02-01    366900.0  4400.0            362500.0  0.012138      139000.0
# 2018-03-01    371600.0  4700.0            366900.0  0.012810      142100.0
# 2018-04-01    376100.0  4500.0            371600.0  0.012110      145000.0
#
#             5 year return        mar
# 2017-12-01     170.940819  33.981388
# 2018-01-01     168.319763  34.146081
# 2018-02-01     163.956835  34.381704
# 2018-03-01     161.505982  34.759700
# 2018-04-01     159.379310  34.753288

# %%
lw_dvar['5 year minus mar'] = lw_dvar['5 year return'] - lw_dvar['mar']
# Out:
# <ipython-input-38-0dfe89c527e9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lw_dvar['5 year minus mar'] = lw_dvar['5 year return'] - lw_dvar['mar']

# %%
lw_dvar.head()
# Out:
#             home price    diff  home price shifted       pct  5 year shift  \
# 2001-04-01    189200.0  3800.0            185400.0  0.020496      108200.0
# 2001-05-01    192800.0  3600.0            189200.0  0.019027      107800.0
# 2001-06-01    196400.0  3600.0            192800.0  0.018672      107500.0
# 2001-07-01    199900.0  3500.0            196400.0  0.017821      107300.0
# 2001-08-01    203200.0  3300.0            199900.0  0.016508      107100.0
#
#             5 year return        mar  5 year minus mar
# 2001-04-01      74.861368  35.180540         39.680828
# 2001-05-01      78.849722  35.760117         43.089605
# 2001-06-01      82.697674  36.308179         46.389496
# 2001-07-01      86.300093  36.831948         49.468145
# 2001-08-01      89.729225  37.328660         52.400565

# %%
lw_dvar['5 year minus mar'].plot();

# %%
lw_down = lw_dvar.loc[lw_dvar['5 year minus mar'] < 0]

# %%
lw_down['neg sq'] = lw_down['5 year minus mar']**2
# Out:
# <ipython-input-42-0c89c2b59d50>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lw_down['neg sq'] = lw_down['5 year minus mar']**2

# %%
lw_down.head(60)
# Out:
#             home price     diff  home price shifted       pct  5 year shift  \
# 2008-01-01    340000.0  -7800.0            347800.0 -0.022427      255500.0
# 2008-02-01    330200.0  -9800.0            340000.0 -0.028824      260100.0
# 2008-03-01    317800.0 -12400.0            330200.0 -0.037553      264700.0
# 2008-04-01    304100.0 -13700.0            317800.0 -0.043109      269300.0
# 2008-05-01    290800.0 -13300.0            304100.0 -0.043736      274000.0
# 2008-06-01    278100.0 -12700.0            290800.0 -0.043673      278600.0
# 2008-07-01    266700.0 -11400.0            278100.0 -0.040992      282900.0
# 2008-08-01    256000.0 -10700.0            266700.0 -0.040120      286700.0
# 2008-09-01    245300.0 -10700.0            256000.0 -0.041797      290000.0
# 2008-10-01    234700.0 -10600.0            245300.0 -0.043212      293000.0
# 2008-11-01    224800.0  -9900.0            234700.0 -0.042182      295800.0
# 2008-12-01    215200.0  -9600.0            224800.0 -0.042705      298800.0
# 2009-01-01    206300.0  -8900.0            215200.0 -0.041357      301900.0
# 2009-02-01    197100.0  -9200.0            206300.0 -0.044595      305300.0
# 2009-03-01    187400.0  -9700.0            197100.0 -0.049214      309300.0
# 2009-04-01    177800.0  -9600.0            187400.0 -0.051227      314100.0
# 2009-05-01    168400.0  -9400.0            177800.0 -0.052868      319300.0
# 2009-06-01    159200.0  -9200.0            168400.0 -0.054632      325200.0
# 2009-07-01    151200.0  -8000.0            159200.0 -0.050251      331400.0
# 2009-08-01    145200.0  -6000.0            151200.0 -0.039683      337600.0
# 2009-09-01    141200.0  -4000.0            145200.0 -0.027548      343900.0
# 2009-10-01    139000.0  -2200.0            141200.0 -0.015581      350400.0
# 2009-11-01    138300.0   -700.0            139000.0 -0.005036      356600.0
# 2009-12-01    138900.0    600.0            138300.0  0.004338      362700.0
# 2010-01-01    138100.0   -800.0            138900.0 -0.005760      368800.0
# 2010-02-01    137500.0   -600.0            138100.0 -0.004345      374500.0
# 2010-03-01    136800.0   -700.0            137500.0 -0.005091      380300.0
# 2010-04-01    135900.0   -900.0            136800.0 -0.006579      386700.0
# 2010-05-01    135100.0   -800.0            135900.0 -0.005887      393300.0
# 2010-06-01    137000.0   1900.0            135100.0  0.014064      399800.0
# 2010-07-01    139600.0   2600.0            137000.0  0.018978      405700.0
# 2010-08-01    142100.0   2500.0            139600.0  0.017908      410600.0
# 2010-09-01    143000.0    900.0            142100.0  0.006334      414400.0
# 2010-10-01    142800.0   -200.0            143000.0 -0.001399      417400.0
# 2010-11-01    142800.0      0.0            142800.0  0.000000      419400.0
# 2010-12-01    141400.0  -1400.0            142800.0 -0.009804      420800.0
# 2011-01-01    138700.0  -2700.0            141400.0 -0.019095      422200.0
# 2011-02-01    137100.0  -1600.0            138700.0 -0.011536      423500.0
# 2011-03-01    138200.0   1100.0            137100.0  0.008023      425000.0
# 2011-04-01    139200.0   1000.0            138200.0  0.007236      426300.0
# 2011-05-01    138700.0   -500.0            139200.0 -0.003592      427000.0
# 2011-06-01    136800.0  -1900.0            138700.0 -0.013699      426000.0
# 2011-07-01    133500.0  -3300.0            136800.0 -0.024123      423600.0
# 2011-08-01    130300.0  -3200.0            133500.0 -0.023970      419700.0
# 2011-09-01    128700.0  -1600.0            130300.0 -0.012279      414900.0
# 2011-10-01    127300.0  -1400.0            128700.0 -0.010878      409600.0
# 2011-11-01    124200.0  -3100.0            127300.0 -0.024352      403900.0
# 2011-12-01    121400.0  -2800.0            124200.0 -0.022544      398700.0
# 2012-01-01    120900.0   -500.0            121400.0 -0.004119      394800.0
# 2012-02-01    121100.0    200.0            120900.0  0.001654      391400.0
# 2012-03-01    121000.0   -100.0            121100.0 -0.000826      388100.0
# 2012-04-01    121400.0    400.0            121000.0  0.003306      385400.0
# 2012-05-01    122300.0    900.0            121400.0  0.007414      383100.0
# 2012-06-01    122800.0    500.0            122300.0  0.004088      379700.0
# 2012-07-01    123800.0   1000.0            122800.0  0.008143      375800.0
# 2012-08-01    125400.0   1600.0            123800.0  0.012924      371200.0
# 2012-09-01    127100.0   1700.0            125400.0  0.013557      366200.0
# 2012-10-01    128300.0   1200.0            127100.0  0.009441      360800.0
# 2012-11-01    129500.0   1200.0            128300.0  0.009353      354800.0
# 2012-12-01    131800.0   2300.0            129500.0  0.017761      347800.0
#
#             5 year return        mar  5 year minus mar       neg sq
# 2008-01-01      33.072407  35.369197         -2.296790     5.275242
# 2008-02-01      26.951173  33.676758         -6.725586    45.233501
# 2008-03-01      20.060446  31.944485        -11.884039   141.230390
# 2008-04-01      12.922391  30.171536        -17.249144   297.532984
# 2008-05-01       6.131387  28.304691        -22.173304   491.655423
# 2008-06-01      -0.179469  26.323177        -26.502646   702.390225
# 2008-07-01      -5.726405  24.351892        -30.078297   904.703945
# 2008-08-01     -10.708057  22.439946        -33.148004  1098.790144
# 2008-09-01     -15.413793  20.616128        -36.029921  1298.155180
# 2008-10-01     -19.897611  18.870624        -38.768235  1502.976059
# 2008-11-01     -24.002705  17.238599        -41.241304  1700.845124
# 2008-12-01     -27.978581  15.720866        -43.699447  1909.641692
# 2009-01-01     -31.666115  14.278833        -45.944948  2110.938241
# 2009-02-01     -35.440550  12.781582        -48.222132  2325.374012
# 2009-03-01     -39.411575  11.216123        -50.627697  2563.163710
# 2009-04-01     -43.393824   9.559015        -52.952838  2804.003071
# 2009-05-01     -47.259630   7.756262        -55.015892  3026.748371
# 2009-06-01     -51.045510   5.900281        -56.945791  3242.823121
# 2009-07-01     -54.375377   4.223820        -58.599197  3433.865884
# 2009-08-01     -56.990521   2.755476        -59.745997  3569.584144
# 2009-09-01     -58.941553   1.425737        -60.367289  3644.209618
# 2009-10-01     -60.331050   0.208098        -60.539148  3664.988431
# 2009-11-01     -61.217050  -0.856990        -60.360060  3643.336801
# 2009-12-01     -61.703888  -1.818190        -59.885698  3586.296807
# 2010-01-01     -62.554230  -2.704675        -59.849554  3581.969169
# 2010-02-01     -63.284379  -3.370576        -59.913804  3589.663851
# 2010-03-01     -64.028399  -4.237766        -59.790632  3574.919721
# 2010-04-01     -64.856478  -5.376238        -59.480239  3537.898888
# 2010-05-01     -65.649631  -6.383811        -59.265820  3512.437474
# 2010-06-01     -65.732866  -7.197056        -58.535811  3426.441114
# 2010-07-01     -65.590338  -8.213400        -57.376938  3292.112999
# 2010-08-01     -65.392109  -9.324265        -56.067844  3143.603154
# 2010-09-01     -65.492278 -10.443201        -55.049077  3030.400858
# 2010-10-01     -65.788213 -11.522753        -54.265460  2944.740113
# 2010-11-01     -65.951359 -12.569527        -53.381832  2849.620003
# 2010-12-01     -66.397338 -13.584979        -52.812359  2789.145295
# 2011-01-01     -67.148271 -14.529276        -52.618995  2768.758634
# 2011-02-01     -67.626919 -15.409081        -52.217838  2726.702574
# 2011-03-01     -67.482353 -16.219228        -51.263125  2627.908000
# 2011-04-01     -67.346939 -16.928417        -50.418521  2542.027295
# 2011-05-01     -67.517564 -17.548889        -49.968676  2496.868546
# 2011-06-01     -67.887324 -18.122112        -49.765212  2476.576360
# 2011-07-01     -68.484419 -18.604641        -49.879778  2487.992299
# 2011-08-01     -68.954015 -18.993113        -49.960902  2496.091705
# 2011-09-01     -68.980477 -19.313767        -49.666710  2466.782082
# 2011-10-01     -68.920898 -19.580350        -49.340548  2434.489692
# 2011-11-01     -69.249814 -19.793786        -49.456029  2445.898777
# 2011-12-01     -69.551041 -19.980201        -49.570840  2457.268144
# 2012-01-01     -69.376900 -20.155457        -49.221443  2422.750447
# 2012-02-01     -69.059785 -20.281538        -48.778248  2379.317444
# 2012-03-01     -68.822468 -20.299279        -48.523190  2354.499929
# 2012-04-01     -68.500259 -20.184850        -48.315410  2334.378811
# 2012-05-01     -68.076220 -19.951844        -48.124376  2315.955567
# 2012-06-01     -67.658678 -19.655825        -48.002853  2304.273908
# 2012-07-01     -67.056945 -19.320952        -47.735993  2278.725014
# 2012-08-01     -66.217672 -18.952510        -47.265162  2233.995546
# 2012-09-01     -65.292190 -18.544472        -46.747718  2185.349111
# 2012-10-01     -64.440133 -18.086238        -46.353895  2148.683569
# 2012-11-01     -63.500564 -17.540508        -45.960056  2112.326718
# 2012-12-01     -62.104658 -16.931786        -45.172872  2040.588339

# %%
lw_down.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 74 entries, 2008-01-01 to 2014-02-01
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   home price          74 non-null     float64
#  1   diff                74 non-null     float64
#  2   home price shifted  74 non-null     float64
#  3   pct                 74 non-null     float64
#  4   5 year shift        74 non-null     float64
#  5   5 year return       74 non-null     float64
#  6   mar                 74 non-null     float64
#  7   5 year minus mar    74 non-null     float64
#  8   neg sq              74 non-null     float64
# dtypes: float64(9)
# memory usage: 5.8 KB

# %%
import numpy as np

np.sqrt(lw_down['neg sq'].sum()/lw_dvar['mar'].count())
# Out:
# 27.678102622623772

# %%
lw_var = lake_worth['5 year return'].dropna()

# %%
lw_var.std()
# Out:
# 89.22884887716472

# %%
lw_var.mean()
# Out:
# 58.86702335165098

# %%
lw_var.describe()
# Out:
# count    205.000000
# mean      58.867023
# std       89.228849
# min      -69.551041
# 25%      -40.944882
# 50%       77.344812
# 75%      148.170129
# max      171.196911
# Name: 5 year return, dtype: float64

# %%
lw_var.plot();

# %%
lake_worth = lake_worth.dropna()

# %%
lake_worth.head()
# Out:
#             home price    diff  home price shifted       pct  5 year shift  \
# 2001-04-01    189200.0  3800.0            185400.0  0.020496      108200.0
# 2001-05-01    192800.0  3600.0            189200.0  0.019027      107800.0
# 2001-06-01    196400.0  3600.0            192800.0  0.018672      107500.0
# 2001-07-01    199900.0  3500.0            196400.0  0.017821      107300.0
# 2001-08-01    203200.0  3300.0            199900.0  0.016508      107100.0
#
#             5 year return
# 2001-04-01      74.861368
# 2001-05-01      78.849722
# 2001-06-01      82.697674
# 2001-07-01      86.300093
# 2001-08-01      89.729225

# %%
lake_worth_pct = lake_worth.drop(['home price','diff','home price shifted'],axis=1)

# %%
lake_worth_pct.head()
# Out:
#                  pct  5 year shift  5 year return
# 2001-04-01  0.020496      108200.0      74.861368
# 2001-05-01  0.019027      107800.0      78.849722
# 2001-06-01  0.018672      107500.0      82.697674
# 2001-07-01  0.017821      107300.0      86.300093
# 2001-08-01  0.016508      107100.0      89.729225

# %%
lake_worth_pct = lake_worth_pct['2013-04':]

# %%
lake_worth_pct.plot();

# %%
from statsmodels.tsa.stattools import adfuller

# %%
adfuller(lake_worth_pct)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-58-cbc2863a4062> in <module>
# ----> 1 adfuller(lake_worth_pct)
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/stattools.py in adfuller(x, maxlag, regression, autolag, store, regresults)
#     247     See example notebook
#     248     """
# --> 249     x = array_like(x, "x")
#     250     maxlag = int_like(maxlag, "maxlag", optional=True)
#     251     regression = string_like(
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tools/validation/validation.py in array_like(obj, name, dtype, ndim, maxdim, shape, order, contiguous, optional)
#     145         if arr.ndim != ndim:
#     146             msg = "{0} is required to have ndim {1} but has ndim {2}"
# --> 147             raise ValueError(msg.format(name, ndim, arr.ndim))
#     148     if shape is not None:
#     149         for actual, req in zip(arr.shape, shape):
#
# ValueError: x is required to have ndim 1 but has ndim 2

# %%
from sklearn.model_selection import TimeSeriesSplit
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
cutoff = '2017-05'
train = lake_worth_pct[:cutoff]
test = lake_worth_pct[cutoff:]

# %%
#Plot_acf is used to identify the q parameter
plot_acf(train);

# %%
plot_pacf(train,method='ywm')

# %%
ar_1 = ARIMA(train, order=(1, 0, 1)).fit()

# We put a typ='levels' to convert our predictions to remove the differencing performed.
train_pred = ar_1.predict()

# %%
from sklearn.metrics import mean_squared_error
import numpy as np

np.sqrt(mean_squared_error(train, train_pred))

# %%
ar_1.summary()

# %%
y_pred = ar_1.get_forecast(len(test.index))
y_pred_df = y_pred.conf_int(alpha = 0.05) 
y_pred_df["Predictions"] = ar_1.predict(start = y_pred_df.index[0], end = y_pred_df.index[-1])
y_pred_df.index = test.index
y_pred_out = y_pred_df["Predictions"]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(train, color = "black",label='Train')
plt.plot(test, color = "red",label='Test')
plt.ylabel('Monthly % Return')
plt.xlabel('Date')
plt.xticks(rotation=45)
plt.title("Train/Test split for Home Price Monthly Return Data")
plt.plot(y_pred_out, color='green', label = 'Predictions')
plt.legend();

# %%
import pandas as pd

# %%
df = pd.read_csv('data/zillow_data.csv')

# %%
df.head()
# Out:
#    RegionID  RegionName      City State              Metro CountyName  \
# 0     84654       60657   Chicago    IL            Chicago       Cook
# 1     90668       75070  McKinney    TX  Dallas-Fort Worth     Collin
# 2     91982       77494      Katy    TX            Houston     Harris
# 3     84616       60614   Chicago    IL            Chicago       Cook
# 4     93144       79936   El Paso    TX            El Paso    El Paso
#
#    SizeRank   1996-04   1996-05   1996-06  ...  2017-07  2017-08  2017-09  \
# 0         1  334200.0  335400.0  336500.0  ...  1005500  1007500  1007800
# 1         2  235700.0  236900.0  236700.0  ...   308000   310000   312500
# 2         3  210400.0  212200.0  212200.0  ...   321000   320600   320200
# 3         4  498100.0  500900.0  503100.0  ...  1289800  1287700  1287400
# 4         5   77300.0   77300.0   77300.0  ...   119100   119400   120000
#
#    2017-10  2017-11  2017-12  2018-01  2018-02  2018-03  2018-04
# 0  1009600  1013300  1018700  1024400  1030700  1033800  1030600
# 1   314100   315000   316600   318100   319600   321100   321800
# 2   320400   320800   321200   321200   323000   326900   329900
# 3  1291500  1296600  1299000  1302700  1306400  1308500  1307000
# 4   120300   120300   120300   120300   120500   121000   121500
#
# [5 rows x 272 columns]

# %%
df = df.rename(columns={'RegionName': 'zipcode'})

# %%
df['zipcode'] = df['zipcode'].astype(str).str.zfill(5)

# %%
df['five_year'] = ((df['2018-04']/df['2013-04'])-1)*100

# %%
df.head()
# Out:
#    RegionID zipcode      City State              Metro CountyName  SizeRank  \
# 0     84654   60657   Chicago    IL            Chicago       Cook         1
# 1     90668   75070  McKinney    TX  Dallas-Fort Worth     Collin         2
# 2     91982   77494      Katy    TX            Houston     Harris         3
# 3     84616   60614   Chicago    IL            Chicago       Cook         4
# 4     93144   79936   El Paso    TX            El Paso    El Paso         5
#
#     1996-04   1996-05   1996-06  ...  2017-08  2017-09  2017-10  2017-11  \
# 0  334200.0  335400.0  336500.0  ...  1007500  1007800  1009600  1013300
# 1  235700.0  236900.0  236700.0  ...   310000   312500   314100   315000
# 2  210400.0  212200.0  212200.0  ...   320600   320200   320400   320800
# 3  498100.0  500900.0  503100.0  ...  1287700  1287400  1291500  1296600
# 4   77300.0   77300.0   77300.0  ...   119400   120000   120300   120300
#
#    2017-12  2018-01  2018-02  2018-03  2018-04  five_year
# 0  1018700  1024400  1030700  1033800  1030600  26.082701
# 1   316600   318100   319600   321100   321800  53.384175
# 2   321200   321200   323000   326900   329900  28.315830
# 3  1299000  1302700  1306400  1308500  1307000  25.878840
# 4   120300   120300   120500   121000   121500   7.048458
#
# [5 rows x 273 columns]

# %%
df[['zipcode','City','State','five_year']].sort_values(by=['five_year'],ascending=False).head(20)
# Out:
#      zipcode              City State   five_year
# 7302   80216            Denver    CO  173.872951
# 1477   94601           Oakland    CA  167.943262
# 5830   48240           Redford    MI  161.224490
# 1239   94590           Vallejo    CA  159.379310
# 2661   33705  Saint Petersburg    FL  159.210526
# 6105   37210         Nashville    TN  155.932203
# 2627   33460        Lake Worth    FL  153.647059
# 6563   15201        Pittsburgh    PA  147.593583
# 475    11216          New York    NY  147.591761
# 1835   37207         Nashville    TN  146.683047
# 1461   33461      Palm Springs    FL  146.335404
# 1273   33435     Boynton Beach    FL  144.760820
# 990    33415        Greenacres    FL  144.613435
# 2988   32807           Orlando    FL  144.415243
# 4146   33030         Homestead    FL  144.167610
# 1463   34207         Bradenton    FL  141.495601
# 3794   33056     Miami Gardens    FL  140.647858
# 1681   94606           Oakland    CA  140.110269
# 1758   30316           Atlanta    GA  140.088106
# 1946   85035           Phoenix    AZ  139.940387

# %%
lake_worth = df.loc[df['zipcode'] == '33460']

# %%
lake_worth.head()
# Out:
#       RegionID zipcode        City State                  Metro  CountyName  \
# 2627     72619   33460  Lake Worth    FL  Miami-Fort Lauderdale  Palm Beach
#
#       SizeRank  1996-04  1996-05  1996-06  ...  2017-08  2017-09  2017-10  \
# 2627      2628  59800.0  59900.0  60000.0  ...   195500   198400   200400
#
#       2017-11  2017-12  2018-01  2018-02  2018-03  2018-04   five_year
# 2627   202600   206000   209600   211600   213300   215600  153.647059
#
# [1 rows x 273 columns]

# %%
lake_worth = lake_worth.iloc[:,7:-1]

# %%
lake_worth.head()
# Out:
#       1996-04  1996-05  1996-06  1996-07  1996-08  1996-09  1996-10  1996-11  \
# 2627  59800.0  59900.0  60000.0  60200.0  60400.0  60700.0  61000.0  61300.0
#
#       1996-12  1997-01  ...  2017-07  2017-08  2017-09  2017-10  2017-11  \
# 2627  61800.0  62400.0  ...   191300   195500   198400   200400   202600
#
#       2017-12  2018-01  2018-02  2018-03  2018-04
# 2627   206000   209600   211600   213300   215600
#
# [1 rows x 265 columns]

# %%
lake_worth = lake_worth.T

# %%
lake_worth.head()
# Out:
#             2627
# 1996-04  59800.0
# 1996-05  59900.0
# 1996-06  60000.0
# 1996-07  60200.0
# 1996-08  60400.0

# %%
type(lake_worth)
# Out:
# pandas.core.frame.DataFrame

# %%
lake_worth = lake_worth.rename(columns={2627:'home price'})

# %%
lake_worth.head()
# Out:
#          home price
# 1996-04     59800.0
# 1996-05     59900.0
# 1996-06     60000.0
# 1996-07     60200.0
# 1996-08     60400.0

# %%
lake_worth.index = lake_worth.index.astype('datetime64[ns]')

# %%
lake_worth.index.dtype
# Out:
# dtype('<M8[ns]')

# %%
lake_worth.plot();

# %%
lake_worth['diff'] = lake_worth.diff()

# %%
lake_worth.head()
# Out:
#             home price   diff
# 1996-04-01     59800.0    NaN
# 1996-05-01     59900.0  100.0
# 1996-06-01     60000.0  100.0
# 1996-07-01     60200.0  200.0
# 1996-08-01     60400.0  200.0

# %%
lake_worth['home price shifted'] = lake_worth['home price'].shift()

# %%
lake_worth.tail()
# Out:
#             home price    diff  home price shifted
# 2017-12-01    206000.0  3400.0            202600.0
# 2018-01-01    209600.0  3600.0            206000.0
# 2018-02-01    211600.0  2000.0            209600.0
# 2018-03-01    213300.0  1700.0            211600.0
# 2018-04-01    215600.0  2300.0            213300.0

# %%
lake_worth['pct'] = lake_worth['diff']/lake_worth['home price shifted']

# %%
lake_worth.head()
# Out:
#             home price   diff  home price shifted       pct
# 1996-04-01     59800.0    NaN                 NaN       NaN
# 1996-05-01     59900.0  100.0             59800.0  0.001672
# 1996-06-01     60000.0  100.0             59900.0  0.001669
# 1996-07-01     60200.0  200.0             60000.0  0.003333
# 1996-08-01     60400.0  200.0             60200.0  0.003322

# %%
lake_worth['5 year shift'] = lake_worth['home price'].shift(60)

# %%
lake_worth.head(61)
# Out:
#             home price   diff  home price shifted       pct  5 year shift
# 1996-04-01     59800.0    NaN                 NaN       NaN           NaN
# 1996-05-01     59900.0  100.0             59800.0  0.001672           NaN
# 1996-06-01     60000.0  100.0             59900.0  0.001669           NaN
# 1996-07-01     60200.0  200.0             60000.0  0.003333           NaN
# 1996-08-01     60400.0  200.0             60200.0  0.003322           NaN
# ...                ...    ...                 ...       ...           ...
# 2000-12-01     85100.0  600.0             84500.0  0.007101           NaN
# 2001-01-01     85800.0  700.0             85100.0  0.008226           NaN
# 2001-02-01     86500.0  700.0             85800.0  0.008159           NaN
# 2001-03-01     87200.0  700.0             86500.0  0.008092           NaN
# 2001-04-01     87900.0  700.0             87200.0  0.008028       59800.0
#
# [61 rows x 5 columns]

# %%
lake_worth['5 year return'] = ((lake_worth['home price']/lake_worth['5 year shift'])-1)*100

# %%
lake_worth.tail()
# Out:
#             home price    diff  home price shifted       pct  5 year shift  \
# 2017-12-01    206000.0  3400.0            202600.0  0.016782       75800.0
# 2018-01-01    209600.0  3600.0            206000.0  0.017476       77600.0
# 2018-02-01    211600.0  2000.0            209600.0  0.009542       79800.0
# 2018-03-01    213300.0  1700.0            211600.0  0.008034       82300.0
# 2018-04-01    215600.0  2300.0            213300.0  0.010783       85000.0
#
#             5 year return
# 2017-12-01     171.767810
# 2018-01-01     170.103093
# 2018-02-01     165.162907
# 2018-03-01     159.173755
# 2018-04-01     153.647059

# %%
lake_worth.head()
# Out:
#             home price   diff  home price shifted       pct  5 year shift  \
# 1996-04-01     59800.0    NaN                 NaN       NaN           NaN
# 1996-05-01     59900.0  100.0             59800.0  0.001672           NaN
# 1996-06-01     60000.0  100.0             59900.0  0.001669           NaN
# 1996-07-01     60200.0  200.0             60000.0  0.003333           NaN
# 1996-08-01     60400.0  200.0             60200.0  0.003322           NaN
#
#             5 year return
# 1996-04-01            NaN
# 1996-05-01            NaN
# 1996-06-01            NaN
# 1996-07-01            NaN
# 1996-08-01            NaN

# %%
lw_dvar = lake_worth.dropna()

# %%
df_mean = pd.read_csv('data/national.csv')

# %%
df_mean.head()
# Out:
#           Unnamed: 0          0
# 0  five-year 2001-04  35.180540
# 1  five-year 2001-05  35.760117
# 2  five-year 2001-06  36.308179
# 3  five-year 2001-07  36.831948
# 4  five-year 2001-08  37.328660

# %%
df_mean.iloc[:,1].values
# Out:
# array([ 35.18053985,  35.76011692,  36.30817887,  36.83194827,
#         37.32865988,  37.8069953 ,  38.27221538,  38.73249943,
#         39.111278  ,  39.4460225 ,  39.83724063,  40.30037615,
#         40.72237946,  41.09422992,  41.43360942,  41.74907935,
#         42.04327701,  42.33381627,  42.59648697,  42.99951262,
#         43.39240939,  43.57326369,  43.62538032,  43.80738873,
#         44.01288126,  44.2614003 ,  44.57818087,  44.96467443,
#         45.38097162,  45.81328425,  46.21790364,  46.55667771,
#         46.75474477,  46.89544351,  47.13687621,  47.55439538,
#         48.08249299,  48.73351988,  49.51166504,  50.37375685,
#         51.24110653,  52.09484394,  52.88972001,  53.56845997,
#         54.0826896 ,  54.45101928,  54.77126623,  55.19703608,
#         55.72187368,  56.2947537 ,  56.91857375,  57.56652767,
#         58.15227369,  58.64489454,  58.99356943,  59.1596511 ,
#         59.11005283,  58.88426206,  58.55733692,  58.27644121,
#         58.01882505,  57.71987763,  57.34617398,  56.88177713,
#         56.28417717,  55.57493772,  54.74936412,  53.81686734,
#         52.83386906,  51.82329395,  50.73004778,  49.64242487,
#         48.56133131,  47.41535353,  46.17818837,  44.8967385 ,
#         43.55008563,  42.14554825,  40.68452462,  38.98826574,
#         37.13337659,  35.36919665,  33.67675816,  31.94448508,
#         30.17153582,  28.30469114,  26.32317685,  24.35189182,
#         22.43994641,  20.61612751,  18.87062426,  17.23859908,
#         15.72086628,  14.27883333,  12.78158169,  11.21612255,
#          9.55901455,   7.75626154,   5.90028062,   4.22381977,
#          2.75547556,   1.42573653,   0.20809769,  -0.85699026,
#         -1.81818966,  -2.70467547,  -3.37057566,  -4.23776625,
#         -5.37623841,  -6.38381087,  -7.19705591,  -8.21339982,
#         -9.3242649 , -10.44320118, -11.52275308, -12.56952694,
#        -13.5849791 , -14.52927597, -15.40908083, -16.21922779,
#        -16.92841743, -17.54888875, -18.1221116 , -18.60464081,
#        -18.99311301, -19.31376722, -19.58035029, -19.79378559,
#        -19.98020123, -20.15545673, -20.28153773, -20.29927883,
#        -20.1848498 , -19.95184429, -19.65582478, -19.32095233,
#        -18.95251034, -18.54447235, -18.08623817, -17.54050802,
#        -16.93178614, -16.29044071, -15.56093517, -14.7097567 ,
#        -13.74038068, -12.66169059, -11.48235149, -10.28820384,
#         -9.1499555 ,  -8.10912986,  -7.12673341,  -6.17631668,
#         -5.27705022,  -4.41703672,  -3.50970341,  -2.53625053,
#         -1.45698488,  -0.19854905,   1.11734141,   2.25009727,
#          3.13422916,   3.82499829,   4.39973588,   4.90160896,
#          5.33868265,   5.75351672,   6.01471595,   6.52398799,
#          7.39171167,   8.21684445,   8.81505649,   9.66265571,
#         10.66644064,  11.72729217,  12.7903877 ,  13.90373299,
#         15.0972819 ,  16.36266533,  17.61098535,  18.76314629,
#         19.87733755,  21.05261618,  22.29716737,  23.51015826,
#         24.62820998,  25.65042234,  26.63819342,  27.60527726,
#         28.50614653,  29.40427079,  30.23923857,  30.86539096,
#         31.33546649,  31.78915127,  32.18735   ,  32.53072575,
#         32.90503973,  33.28267069,  33.5877789 ,  33.78443833,
#         33.98138802,  34.14608058,  34.38170443,  34.75969992,
#         34.75328789])

# %%
lw_dvar['mar'] = df_mean.iloc[:,1].values
# Out:
# <ipython-input-90-27c190f2f8ee>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lw_dvar['mar'] = df_mean.iloc[:,1].values

# %%
lw_dvar.tail()
# Out:
#             home price    diff  home price shifted       pct  5 year shift  \
# 2017-12-01    206000.0  3400.0            202600.0  0.016782       75800.0
# 2018-01-01    209600.0  3600.0            206000.0  0.017476       77600.0
# 2018-02-01    211600.0  2000.0            209600.0  0.009542       79800.0
# 2018-03-01    213300.0  1700.0            211600.0  0.008034       82300.0
# 2018-04-01    215600.0  2300.0            213300.0  0.010783       85000.0
#
#             5 year return        mar
# 2017-12-01     171.767810  33.981388
# 2018-01-01     170.103093  34.146081
# 2018-02-01     165.162907  34.381704
# 2018-03-01     159.173755  34.759700
# 2018-04-01     153.647059  34.753288

# %%
lw_dvar['5 year minus mar'] = lw_dvar['5 year return'] - lw_dvar['mar']
# Out:
# <ipython-input-92-0dfe89c527e9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lw_dvar['5 year minus mar'] = lw_dvar['5 year return'] - lw_dvar['mar']

# %%
lw_dvar.head()
# Out:
#             home price   diff  home price shifted       pct  5 year shift  \
# 2001-04-01     87900.0  700.0             87200.0  0.008028       59800.0
# 2001-05-01     88500.0  600.0             87900.0  0.006826       59900.0
# 2001-06-01     89200.0  700.0             88500.0  0.007910       60000.0
# 2001-07-01     89900.0  700.0             89200.0  0.007848       60200.0
# 2001-08-01     90700.0  800.0             89900.0  0.008899       60400.0
#
#             5 year return        mar  5 year minus mar
# 2001-04-01      46.989967  35.180540         11.809427
# 2001-05-01      47.746244  35.760117         11.986127
# 2001-06-01      48.666667  36.308179         12.358488
# 2001-07-01      49.335548  36.831948         12.503600
# 2001-08-01      50.165563  37.328660         12.836903

# %%
lw_down = lw_dvar.loc[lw_dvar['5 year minus mar'] < 0]

# %%
lw_down['neg sq'] = lw_down['5 year minus mar']**2
# Out:
# <ipython-input-95-0c89c2b59d50>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lw_down['neg sq'] = lw_down['5 year minus mar']**2

# %%
lw_down.head(60)
# Out:
#             home price    diff  home price shifted       pct  5 year shift  \
# 2008-11-01    157000.0 -5600.0            162600.0 -0.034440      135400.0
# 2008-12-01    151400.0 -5600.0            157000.0 -0.035669      137700.0
# 2009-01-01    145800.0 -5600.0            151400.0 -0.036988      140200.0
# 2009-02-01    140000.0 -5800.0            145800.0 -0.039781      142800.0
# 2009-03-01    134100.0 -5900.0            140000.0 -0.042143      145300.0
# 2009-04-01    128300.0 -5800.0            134100.0 -0.043251      148000.0
# 2009-05-01    122300.0 -6000.0            128300.0 -0.046765      150900.0
# 2009-06-01    116400.0 -5900.0            122300.0 -0.048242      154200.0
# 2009-07-01    111200.0 -5200.0            116400.0 -0.044674      157800.0
# 2009-08-01    107100.0 -4100.0            111200.0 -0.036871      161700.0
# 2009-09-01    104200.0 -2900.0            107100.0 -0.027077      165700.0
# 2009-10-01    102400.0 -1800.0            104200.0 -0.017274      169700.0
# 2009-11-01    101700.0  -700.0            102400.0 -0.006836      173700.0
# 2009-12-01    101800.0   100.0            101700.0  0.000983      177900.0
# 2010-01-01    102000.0   200.0            101800.0  0.001965      182400.0
# 2010-02-01    102100.0   100.0            102000.0  0.000980      187400.0
# 2010-03-01    101300.0  -800.0            102100.0 -0.007835      193000.0
# 2010-04-01    100000.0 -1300.0            101300.0 -0.012833      199400.0
# 2010-05-01     99800.0  -200.0            100000.0 -0.002000      206100.0
# 2010-06-01    100500.0   700.0             99800.0  0.007014      213100.0
# 2010-07-01    100300.0  -200.0            100500.0 -0.001990      220200.0
# 2010-08-01     99000.0 -1300.0            100300.0 -0.012961      227000.0
# 2010-09-01     97300.0 -1700.0             99000.0 -0.017172      233200.0
# 2010-10-01     95300.0 -2000.0             97300.0 -0.020555      238400.0
# 2010-11-01     92600.0 -2700.0             95300.0 -0.028332      242800.0
# 2010-12-01     89600.0 -3000.0             92600.0 -0.032397      246500.0
# 2011-01-01     87200.0 -2400.0             89600.0 -0.026786      249600.0
# 2011-02-01     85100.0 -2100.0             87200.0 -0.024083      252300.0
# 2011-03-01     83000.0 -2100.0             85100.0 -0.024677      255000.0
# 2011-04-01     80600.0 -2400.0             83000.0 -0.028916      257300.0
# 2011-05-01     78200.0 -2400.0             80600.0 -0.029777      258700.0
# 2011-06-01     76100.0 -2100.0             78200.0 -0.026854      259200.0
# 2011-07-01     74800.0 -1300.0             76100.0 -0.017083      259100.0
# 2011-08-01     74100.0  -700.0             74800.0 -0.009358      258300.0
# 2011-09-01     73600.0  -500.0             74100.0 -0.006748      257200.0
# 2011-10-01     73000.0  -600.0             73600.0 -0.008152      255800.0
# 2011-11-01     72400.0  -600.0             73000.0 -0.008219      254200.0
# 2011-12-01     71600.0  -800.0             72400.0 -0.011050      252400.0
# 2012-01-01     70600.0 -1000.0             71600.0 -0.013966      250400.0
# 2012-02-01     69800.0  -800.0             70600.0 -0.011331      247800.0
# 2012-03-01     69400.0  -400.0             69800.0 -0.005731      244700.0
# 2012-04-01     69700.0   300.0             69400.0  0.004323      241500.0
# 2012-05-01     70700.0  1000.0             69700.0  0.014347      237800.0
# 2012-06-01     71500.0   800.0             70700.0  0.011315      234000.0
# 2012-07-01     71600.0   100.0             71500.0  0.001399      230400.0
# 2012-08-01     71400.0  -200.0             71600.0 -0.002793      226600.0
# 2012-09-01     71700.0   300.0             71400.0  0.004202      222400.0
# 2012-10-01     72600.0   900.0             71700.0  0.012552      217700.0
# 2012-11-01     74000.0  1400.0             72600.0  0.019284      212900.0
# 2012-12-01     75800.0  1800.0             74000.0  0.024324      208300.0
# 2013-01-01     77600.0  1800.0             75800.0  0.023747      203800.0
# 2013-02-01     79800.0  2200.0             77600.0  0.028351      199500.0
# 2013-03-01     82300.0  2500.0             79800.0  0.031328      195500.0
# 2013-04-01     85000.0  2700.0             82300.0  0.032807      192000.0
# 2013-05-01     87100.0  2100.0             85000.0  0.024706      188000.0
# 2013-06-01     88700.0  1600.0             87100.0  0.018370      183700.0
# 2013-07-01     91100.0  2400.0             88700.0  0.027057      179000.0
# 2013-08-01     94500.0  3400.0             91100.0  0.037322      173800.0
# 2013-09-01     97200.0  2700.0             94500.0  0.028571      168300.0
# 2013-10-01     99700.0  2500.0             97200.0  0.025720      162600.0
#
#             5 year return        mar  5 year minus mar       neg sq
# 2008-11-01      15.952733  17.238599         -1.285866     1.653453
# 2008-12-01       9.949165  15.720866         -5.771701    33.312537
# 2009-01-01       3.994294  14.278833        -10.284539   105.771752
# 2009-02-01      -1.960784  12.781582        -14.742366   217.337355
# 2009-03-01      -7.708190  11.216123        -18.924312   358.129603
# 2009-04-01     -13.310811   9.559015        -22.869825   523.028912
# 2009-05-01     -18.952949   7.756262        -26.709211   713.381926
# 2009-06-01     -24.513619   5.900281        -30.413899   925.005271
# 2009-07-01     -29.531052   4.223820        -33.754872  1139.391366
# 2009-08-01     -33.766234   2.755476        -36.521709  1333.835252
# 2009-09-01     -37.115269   1.425737        -38.541005  1485.409073
# 2009-10-01     -39.658220   0.208098        -39.866318  1589.323317
# 2009-11-01     -41.450777  -0.856990        -40.593787  1647.855538
# 2009-12-01     -42.776841  -1.818190        -40.958651  1677.611113
# 2010-01-01     -44.078947  -2.704675        -41.374272  1711.830375
# 2010-02-01     -45.517609  -3.370576        -42.147034  1776.372452
# 2010-03-01     -47.512953  -4.237766        -43.275187  1872.741820
# 2010-04-01     -49.849549  -5.376238        -44.473310  1977.875323
# 2010-05-01     -51.576904  -6.383811        -45.193094  2042.415704
# 2010-06-01     -52.839043  -7.197056        -45.641987  2083.190959
# 2010-07-01     -54.450500  -8.213400        -46.237100  2137.869391
# 2010-08-01     -56.387665  -9.324265        -47.063400  2214.963648
# 2010-09-01     -58.276158 -10.443201        -47.832957  2287.991739
# 2010-10-01     -60.025168 -11.522753        -48.502415  2352.484233
# 2010-11-01     -61.861614 -12.569527        -49.292088  2429.709896
# 2010-12-01     -63.651116 -13.584979        -50.066137  2506.618026
# 2011-01-01     -65.064103 -14.529276        -50.534827  2553.768699
# 2011-02-01     -66.270313 -15.409081        -50.861232  2586.864950
# 2011-03-01     -67.450980 -16.219228        -51.231753  2624.692475
# 2011-04-01     -68.674699 -16.928417        -51.746281  2677.677635
# 2011-05-01     -69.771937 -17.548889        -52.223048  2727.246727
# 2011-06-01     -70.640432 -18.122112        -52.518321  2758.173988
# 2011-07-01     -71.130838 -18.604641        -52.526197  2759.001341
# 2011-08-01     -71.312427 -18.993113        -52.319314  2737.310659
# 2011-09-01     -71.384137 -19.313767        -52.070370  2711.323394
# 2011-10-01     -71.462080 -19.580350        -51.881729  2691.713852
# 2011-11-01     -71.518489 -19.793786        -51.724704  2675.444983
# 2011-12-01     -71.632330 -19.980201        -51.652128  2667.942369
# 2012-01-01     -71.805112 -20.155457        -51.649655  2667.686871
# 2012-02-01     -71.832123 -20.281538        -51.550585  2657.462809
# 2012-03-01     -71.638741 -20.299279        -51.339462  2635.740408
# 2012-04-01     -71.138716 -20.184850        -50.953867  2596.296517
# 2012-05-01     -70.269134 -19.951844        -50.317289  2531.829616
# 2012-06-01     -69.444444 -19.655825        -49.788620  2478.906648
# 2012-07-01     -68.923611 -19.320952        -49.602659  2460.423758
# 2012-08-01     -68.490733 -18.952510        -49.538222  2454.035462
# 2012-09-01     -67.760791 -18.544472        -49.216319  2422.246058
# 2012-10-01     -66.651355 -18.086238        -48.565117  2358.570580
# 2012-11-01     -65.241898 -17.540508        -47.701390  2275.422568
# 2012-12-01     -63.610178 -16.931786        -46.678391  2178.872232
# 2013-01-01     -61.923454 -16.290441        -45.633014  2082.371936
# 2013-02-01     -60.000000 -15.560935        -44.439065  1974.830483
# 2013-03-01     -57.902813 -14.709757        -43.193057  1865.640138
# 2013-04-01     -55.729167 -13.740381        -41.988786  1763.058148
# 2013-05-01     -53.670213 -12.661691        -41.008522  1681.698891
# 2013-06-01     -51.714752 -11.482351        -40.232401  1618.646076
# 2013-07-01     -49.106145 -10.288204        -38.817941  1506.832576
# 2013-08-01     -45.627158  -9.149956        -36.477202  1330.586277
# 2013-09-01     -42.245989  -8.109130        -34.136859  1165.325173
# 2013-10-01     -38.683887  -7.126733        -31.557153   995.853933

# %%
lw_down.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 68 entries, 2008-11-01 to 2014-06-01
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   home price          68 non-null     float64
#  1   diff                68 non-null     float64
#  2   home price shifted  68 non-null     float64
#  3   pct                 68 non-null     float64
#  4   5 year shift        68 non-null     float64
#  5   5 year return       68 non-null     float64
#  6   mar                 68 non-null     float64
#  7   5 year minus mar    68 non-null     float64
#  8   neg sq              68 non-null     float64
# dtypes: float64(9)
# memory usage: 5.3 KB

# %%
import numpy as np

np.sqrt(lw_down['neg sq'].sum()/lw_down['neg sq'].count())
# Out:
# 41.5990295853736

# %%
lw_var = lake_worth['5 year return'].dropna()

# %%
lw_var.std()
# Out:
# 85.07622645166362

# %%
lw_var.mean()
# Out:
# 54.0368829557541

# %%
lw_var.describe()
# Out:
# count    206.000000
# mean      53.871655
# std       84.901596
# min      -71.832123
# 25%      -33.036036
# 50%       57.167779
# 75%      124.909945
# max      192.718999
# Name: 5 year return, dtype: float64

# %%
lw_var.plot();

# %%
lake_worth = lake_worth.dropna()

# %%
lake_worth.head()
# Out:
#             home price   diff  home price shifted       pct
# 1996-05-01     59900.0  100.0             59800.0  0.001672
# 1996-06-01     60000.0  100.0             59900.0  0.001669
# 1996-07-01     60200.0  200.0             60000.0  0.003333
# 1996-08-01     60400.0  200.0             60200.0  0.003322
# 1996-09-01     60700.0  300.0             60400.0  0.004967

# %%
lake_worth_pct = lake_worth.drop(['home price','diff','home price shifted'],axis=1)

# %%
lake_worth_pct.head()
# Out:
#                  pct
# 1996-05-01  0.001672
# 1996-06-01  0.001669
# 1996-07-01  0.003333
# 1996-08-01  0.003322
# 1996-09-01  0.004967

# %%
lake_worth_pct = lake_worth_pct['2013-04':]

# %%
lake_worth_pct.plot();

# %%
from statsmodels.tsa.stattools import adfuller

# %%
adfuller(lake_worth_pct)
# Out:
# (-3.6685402773178515,
#  0.004578065501380513,
#  6,
#  54,
#  {'1%': -3.55770911573439,
#   '5%': -2.9167703434435808,
#   '10%': -2.59622219478738},
#  -442.20977364927535)

# %%
from sklearn.model_selection import TimeSeriesSplit
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
cutoff = '2017-05'
train = lake_worth_pct[:cutoff]
test = lake_worth_pct[cutoff:]

# %%
#Plot_acf is used to identify the q parameter
plot_acf(train);

# %%
plot_pacf(train,method='ywm')

# %%
ar_1 = ARIMA(train, order=(1, 0, 1)).fit()

# We put a typ='levels' to convert our predictions to remove the differencing performed.
train_pred = ar_1.predict()
# Out:
# /Users/johnnahra/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/johnnahra/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/johnnahra/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'

# %%
from sklearn.metrics import mean_squared_error
import numpy as np

np.sqrt(mean_squared_error(train, train_pred))
# Out:
# 0.0040740516947202175

# %%
ar_1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                    pct   No. Observations:                   50
# Model:                 ARIMA(1, 0, 1)   Log Likelihood                 210.242
# Date:                Tue, 28 Mar 2023   AIC                           -412.484
# Time:                        00:56:59   BIC                           -404.836
# Sample:                    04-01-2013   HQIC                          -409.571
#                          - 05-01-2017
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0173      0.003      6.403      0.000       0.012       0.023
# ar.L1          0.6863      0.102      6.734      0.000       0.487       0.886
# ma.L1          0.6950      0.120      5.791      0.000       0.460       0.930
# sigma2      1.247e-05   2.42e-06      5.161      0.000    7.74e-06    1.72e-05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.63   Jarque-Bera (JB):                 2.80
# Prob(Q):                              0.43   Prob(JB):                         0.25
# Heteroskedasticity (H):               0.20   Skew:                             0.51
# Prob(H) (two-sided):                  0.00   Kurtosis:                         3.53
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
y_pred = ar_1.get_forecast(len(test.index))
y_pred_df = y_pred.conf_int(alpha = 0.05) 
y_pred_df["Predictions"] = ar_1.predict(start = y_pred_df.index[0], end = y_pred_df.index[-1])
y_pred_df.index = test.index
y_pred_out = y_pred_df["Predictions"]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(train, color = "black",label='Train')
plt.plot(test, color = "red",label='Test')
plt.ylabel('Monthly % Return')
plt.xlabel('Date')
plt.xticks(rotation=45)
plt.title("Train/Test split for Home Price Monthly Return Data")
plt.plot(y_pred_out, color='green', label = 'Predictions')
plt.legend();

# %%
import pandas as pd

# %%
df = pd.read_csv('data/zillow_data.csv')

# %%
df.head()
# Out:
#    RegionID  RegionName      City State              Metro CountyName  \
# 0     84654       60657   Chicago    IL            Chicago       Cook
# 1     90668       75070  McKinney    TX  Dallas-Fort Worth     Collin
# 2     91982       77494      Katy    TX            Houston     Harris
# 3     84616       60614   Chicago    IL            Chicago       Cook
# 4     93144       79936   El Paso    TX            El Paso    El Paso
#
#    SizeRank   1996-04   1996-05   1996-06  ...  2017-07  2017-08  2017-09  \
# 0         1  334200.0  335400.0  336500.0  ...  1005500  1007500  1007800
# 1         2  235700.0  236900.0  236700.0  ...   308000   310000   312500
# 2         3  210400.0  212200.0  212200.0  ...   321000   320600   320200
# 3         4  498100.0  500900.0  503100.0  ...  1289800  1287700  1287400
# 4         5   77300.0   77300.0   77300.0  ...   119100   119400   120000
#
#    2017-10  2017-11  2017-12  2018-01  2018-02  2018-03  2018-04
# 0  1009600  1013300  1018700  1024400  1030700  1033800  1030600
# 1   314100   315000   316600   318100   319600   321100   321800
# 2   320400   320800   321200   321200   323000   326900   329900
# 3  1291500  1296600  1299000  1302700  1306400  1308500  1307000
# 4   120300   120300   120300   120300   120500   121000   121500
#
# [5 rows x 272 columns]

# %%
df = df.rename(columns={'RegionName': 'zipcode'})

# %%
df['zipcode'] = df['zipcode'].astype(str).str.zfill(5)

# %%
df['five_year'] = ((df['2018-04']/df['2013-04'])-1)*100

# %%
df.head()
# Out:
#    RegionID zipcode      City State              Metro CountyName  SizeRank  \
# 0     84654   60657   Chicago    IL            Chicago       Cook         1
# 1     90668   75070  McKinney    TX  Dallas-Fort Worth     Collin         2
# 2     91982   77494      Katy    TX            Houston     Harris         3
# 3     84616   60614   Chicago    IL            Chicago       Cook         4
# 4     93144   79936   El Paso    TX            El Paso    El Paso         5
#
#     1996-04   1996-05   1996-06  ...  2017-08  2017-09  2017-10  2017-11  \
# 0  334200.0  335400.0  336500.0  ...  1007500  1007800  1009600  1013300
# 1  235700.0  236900.0  236700.0  ...   310000   312500   314100   315000
# 2  210400.0  212200.0  212200.0  ...   320600   320200   320400   320800
# 3  498100.0  500900.0  503100.0  ...  1287700  1287400  1291500  1296600
# 4   77300.0   77300.0   77300.0  ...   119400   120000   120300   120300
#
#    2017-12  2018-01  2018-02  2018-03  2018-04  five_year
# 0  1018700  1024400  1030700  1033800  1030600  26.082701
# 1   316600   318100   319600   321100   321800  53.384175
# 2   321200   321200   323000   326900   329900  28.315830
# 3  1299000  1302700  1306400  1308500  1307000  25.878840
# 4   120300   120300   120500   121000   121500   7.048458
#
# [5 rows x 273 columns]

# %%
df[['zipcode','City','State','five_year']].sort_values(by=['five_year'],ascending=False).head(20)
# Out:
#      zipcode              City State   five_year
# 7302   80216            Denver    CO  173.872951
# 1477   94601           Oakland    CA  167.943262
# 5830   48240           Redford    MI  161.224490
# 1239   94590           Vallejo    CA  159.379310
# 2661   33705  Saint Petersburg    FL  159.210526
# 6105   37210         Nashville    TN  155.932203
# 2627   33460        Lake Worth    FL  153.647059
# 6563   15201        Pittsburgh    PA  147.593583
# 475    11216          New York    NY  147.591761
# 1835   37207         Nashville    TN  146.683047
# 1461   33461      Palm Springs    FL  146.335404
# 1273   33435     Boynton Beach    FL  144.760820
# 990    33415        Greenacres    FL  144.613435
# 2988   32807           Orlando    FL  144.415243
# 4146   33030         Homestead    FL  144.167610
# 1463   34207         Bradenton    FL  141.495601
# 3794   33056     Miami Gardens    FL  140.647858
# 1681   94606           Oakland    CA  140.110269
# 1758   30316           Atlanta    GA  140.088106
# 1946   85035           Phoenix    AZ  139.940387

# %%
lake_worth = df.loc[df['zipcode'] == '37207']

# %%
lake_worth.head()
# Out:
#       RegionID zipcode       City State      Metro CountyName  SizeRank  \
# 1835     74238   37207  Nashville    TN  Nashville   Davidson      1836
#
#       1996-04  1996-05  1996-06  ...  2017-08  2017-09  2017-10  2017-11  \
# 1835  63600.0  63600.0  63600.0  ...   180700   184200   186700   188000
#
#       2017-12  2018-01  2018-02  2018-03  2018-04   five_year
# 1835   189500   191400   193900   197600   200800  146.683047
#
# [1 rows x 273 columns]

# %%
lake_worth = lake_worth.iloc[:,7:-1]

# %%
lake_worth.head()
# Out:
#       1996-04  1996-05  1996-06  1996-07  1996-08  1996-09  1996-10  1996-11  \
# 1835  63600.0  63600.0  63600.0  63700.0  64000.0  64300.0  64800.0  65400.0
#
#       1996-12  1997-01  ...  2017-07  2017-08  2017-09  2017-10  2017-11  \
# 1835  66000.0  66700.0  ...   177300   180700   184200   186700   188000
#
#       2017-12  2018-01  2018-02  2018-03  2018-04
# 1835   189500   191400   193900   197600   200800
#
# [1 rows x 265 columns]

# %%
lake_worth = lake_worth.T

# %%
lake_worth.head()
# Out:
#             1835
# 1996-04  63600.0
# 1996-05  63600.0
# 1996-06  63600.0
# 1996-07  63700.0
# 1996-08  64000.0

# %%
type(lake_worth)
# Out:
# pandas.core.frame.DataFrame

# %%
lake_worth = lake_worth.rename(columns={1835:'home price'})

# %%
lake_worth.head()
# Out:
#          home price
# 1996-04     63600.0
# 1996-05     63600.0
# 1996-06     63600.0
# 1996-07     63700.0
# 1996-08     64000.0

# %%
lake_worth.index = lake_worth.index.astype('datetime64[ns]')

# %%
lake_worth.index.dtype
# Out:
# dtype('<M8[ns]')

# %%
lake_worth.plot();

# %%
lake_worth['diff'] = lake_worth.diff()

# %%
lake_worth.head()
# Out:
#             home price   diff
# 1996-04-01     63600.0    NaN
# 1996-05-01     63600.0    0.0
# 1996-06-01     63600.0    0.0
# 1996-07-01     63700.0  100.0
# 1996-08-01     64000.0  300.0

# %%
lake_worth['home price shifted'] = lake_worth['home price'].shift()

# %%
lake_worth.tail()
# Out:
#             home price    diff  home price shifted
# 2017-12-01    189500.0  1500.0            188000.0
# 2018-01-01    191400.0  1900.0            189500.0
# 2018-02-01    193900.0  2500.0            191400.0
# 2018-03-01    197600.0  3700.0            193900.0
# 2018-04-01    200800.0  3200.0            197600.0

# %%
lake_worth['pct'] = lake_worth['diff']/lake_worth['home price shifted']

# %%
lake_worth.head()
# Out:
#             home price   diff  home price shifted       pct
# 1996-04-01     63600.0    NaN                 NaN       NaN
# 1996-05-01     63600.0    0.0             63600.0  0.000000
# 1996-06-01     63600.0    0.0             63600.0  0.000000
# 1996-07-01     63700.0  100.0             63600.0  0.001572
# 1996-08-01     64000.0  300.0             63700.0  0.004710

# %%
lake_worth['5 year shift'] = lake_worth['home price'].shift(60)

# %%
lake_worth.head(61)
# Out:
#             home price   diff  home price shifted       pct  5 year shift
# 1996-04-01     63600.0    NaN                 NaN       NaN           NaN
# 1996-05-01     63600.0    0.0             63600.0  0.000000           NaN
# 1996-06-01     63600.0    0.0             63600.0  0.000000           NaN
# 1996-07-01     63700.0  100.0             63600.0  0.001572           NaN
# 1996-08-01     64000.0  300.0             63700.0  0.004710           NaN
# ...                ...    ...                 ...       ...           ...
# 2000-12-01     82600.0  400.0             82200.0  0.004866           NaN
# 2001-01-01     83000.0  400.0             82600.0  0.004843           NaN
# 2001-02-01     83500.0  500.0             83000.0  0.006024           NaN
# 2001-03-01     83800.0  300.0             83500.0  0.003593           NaN
# 2001-04-01     84100.0  300.0             83800.0  0.003580       63600.0
#
# [61 rows x 5 columns]

# %%
lake_worth['5 year return'] = ((lake_worth['home price']/lake_worth['5 year shift'])-1)*100

# %%
lake_worth.tail()
# Out:
#             home price    diff  home price shifted       pct  5 year shift  \
# 2017-12-01    189500.0  1500.0            188000.0  0.007979       78800.0
# 2018-01-01    191400.0  1900.0            189500.0  0.010026       78900.0
# 2018-02-01    193900.0  2500.0            191400.0  0.013062       79000.0
# 2018-03-01    197600.0  3700.0            193900.0  0.019082       79900.0
# 2018-04-01    200800.0  3200.0            197600.0  0.016194       81400.0
#
#             5 year return
# 2017-12-01     140.482234
# 2018-01-01     142.585551
# 2018-02-01     145.443038
# 2018-03-01     147.309136
# 2018-04-01     146.683047

# %%
lake_worth.head()
# Out:
#             home price   diff  home price shifted       pct  5 year shift  \
# 1996-04-01     63600.0    NaN                 NaN       NaN           NaN
# 1996-05-01     63600.0    0.0             63600.0  0.000000           NaN
# 1996-06-01     63600.0    0.0             63600.0  0.000000           NaN
# 1996-07-01     63700.0  100.0             63600.0  0.001572           NaN
# 1996-08-01     64000.0  300.0             63700.0  0.004710           NaN
#
#             5 year return
# 1996-04-01            NaN
# 1996-05-01            NaN
# 1996-06-01            NaN
# 1996-07-01            NaN
# 1996-08-01            NaN

# %%
lw_dvar = lake_worth.dropna()

# %%
df_mean = pd.read_csv('data/national.csv')

# %%
df_mean.head()
# Out:
#           Unnamed: 0          0
# 0  five-year 2001-04  35.180540
# 1  five-year 2001-05  35.760117
# 2  five-year 2001-06  36.308179
# 3  five-year 2001-07  36.831948
# 4  five-year 2001-08  37.328660

# %%
df_mean.iloc[:,1].values
# Out:
# array([ 35.18053985,  35.76011692,  36.30817887,  36.83194827,
#         37.32865988,  37.8069953 ,  38.27221538,  38.73249943,
#         39.111278  ,  39.4460225 ,  39.83724063,  40.30037615,
#         40.72237946,  41.09422992,  41.43360942,  41.74907935,
#         42.04327701,  42.33381627,  42.59648697,  42.99951262,
#         43.39240939,  43.57326369,  43.62538032,  43.80738873,
#         44.01288126,  44.2614003 ,  44.57818087,  44.96467443,
#         45.38097162,  45.81328425,  46.21790364,  46.55667771,
#         46.75474477,  46.89544351,  47.13687621,  47.55439538,
#         48.08249299,  48.73351988,  49.51166504,  50.37375685,
#         51.24110653,  52.09484394,  52.88972001,  53.56845997,
#         54.0826896 ,  54.45101928,  54.77126623,  55.19703608,
#         55.72187368,  56.2947537 ,  56.91857375,  57.56652767,
#         58.15227369,  58.64489454,  58.99356943,  59.1596511 ,
#         59.11005283,  58.88426206,  58.55733692,  58.27644121,
#         58.01882505,  57.71987763,  57.34617398,  56.88177713,
#         56.28417717,  55.57493772,  54.74936412,  53.81686734,
#         52.83386906,  51.82329395,  50.73004778,  49.64242487,
#         48.56133131,  47.41535353,  46.17818837,  44.8967385 ,
#         43.55008563,  42.14554825,  40.68452462,  38.98826574,
#         37.13337659,  35.36919665,  33.67675816,  31.94448508,
#         30.17153582,  28.30469114,  26.32317685,  24.35189182,
#         22.43994641,  20.61612751,  18.87062426,  17.23859908,
#         15.72086628,  14.27883333,  12.78158169,  11.21612255,
#          9.55901455,   7.75626154,   5.90028062,   4.22381977,
#          2.75547556,   1.42573653,   0.20809769,  -0.85699026,
#         -1.81818966,  -2.70467547,  -3.37057566,  -4.23776625,
#         -5.37623841,  -6.38381087,  -7.19705591,  -8.21339982,
#         -9.3242649 , -10.44320118, -11.52275308, -12.56952694,
#        -13.5849791 , -14.52927597, -15.40908083, -16.21922779,
#        -16.92841743, -17.54888875, -18.1221116 , -18.60464081,
#        -18.99311301, -19.31376722, -19.58035029, -19.79378559,
#        -19.98020123, -20.15545673, -20.28153773, -20.29927883,
#        -20.1848498 , -19.95184429, -19.65582478, -19.32095233,
#        -18.95251034, -18.54447235, -18.08623817, -17.54050802,
#        -16.93178614, -16.29044071, -15.56093517, -14.7097567 ,
#        -13.74038068, -12.66169059, -11.48235149, -10.28820384,
#         -9.1499555 ,  -8.10912986,  -7.12673341,  -6.17631668,
#         -5.27705022,  -4.41703672,  -3.50970341,  -2.53625053,
#         -1.45698488,  -0.19854905,   1.11734141,   2.25009727,
#          3.13422916,   3.82499829,   4.39973588,   4.90160896,
#          5.33868265,   5.75351672,   6.01471595,   6.52398799,
#          7.39171167,   8.21684445,   8.81505649,   9.66265571,
#         10.66644064,  11.72729217,  12.7903877 ,  13.90373299,
#         15.0972819 ,  16.36266533,  17.61098535,  18.76314629,
#         19.87733755,  21.05261618,  22.29716737,  23.51015826,
#         24.62820998,  25.65042234,  26.63819342,  27.60527726,
#         28.50614653,  29.40427079,  30.23923857,  30.86539096,
#         31.33546649,  31.78915127,  32.18735   ,  32.53072575,
#         32.90503973,  33.28267069,  33.5877789 ,  33.78443833,
#         33.98138802,  34.14608058,  34.38170443,  34.75969992,
#         34.75328789])

# %%
lw_dvar['mar'] = df_mean.iloc[:,1].values
# Out:
# <ipython-input-51-27c190f2f8ee>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lw_dvar['mar'] = df_mean.iloc[:,1].values

# %%
lw_dvar.tail()
# Out:
#             home price    diff  home price shifted       pct  5 year shift  \
# 2017-12-01    189500.0  1500.0            188000.0  0.007979       78800.0
# 2018-01-01    191400.0  1900.0            189500.0  0.010026       78900.0
# 2018-02-01    193900.0  2500.0            191400.0  0.013062       79000.0
# 2018-03-01    197600.0  3700.0            193900.0  0.019082       79900.0
# 2018-04-01    200800.0  3200.0            197600.0  0.016194       81400.0
#
#             5 year return        mar
# 2017-12-01     140.482234  33.981388
# 2018-01-01     142.585551  34.146081
# 2018-02-01     145.443038  34.381704
# 2018-03-01     147.309136  34.759700
# 2018-04-01     146.683047  34.753288

# %%
lw_dvar['5 year minus mar'] = lw_dvar['5 year return'] - lw_dvar['mar']
# Out:
# <ipython-input-53-0dfe89c527e9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lw_dvar['5 year minus mar'] = lw_dvar['5 year return'] - lw_dvar['mar']

# %%
lw_dvar.head()
# Out:
#             home price   diff  home price shifted       pct  5 year shift  \
# 2001-04-01     84100.0  300.0             83800.0  0.003580       63600.0
# 2001-05-01     84200.0  100.0             84100.0  0.001189       63600.0
# 2001-06-01     84100.0 -100.0             84200.0 -0.001188       63600.0
# 2001-07-01     83900.0 -200.0             84100.0 -0.002378       63700.0
# 2001-08-01     83700.0 -200.0             83900.0 -0.002384       64000.0
#
#             5 year return        mar  5 year minus mar
# 2001-04-01      32.232704  35.180540         -2.947835
# 2001-05-01      32.389937  35.760117         -3.370180
# 2001-06-01      32.232704  36.308179         -4.075474
# 2001-07-01      31.711146  36.831948         -5.120802
# 2001-08-01      30.781250  37.328660         -6.547410

# %%
lw_dvar['5 year minus mar'].plot();

# %%
lw_down = lw_dvar.loc[lw_dvar['5 year minus mar'] < 0]

# %%
lw_down['neg sq'] = lw_down['5 year minus mar']**2
# Out:
# <ipython-input-57-0c89c2b59d50>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lw_down['neg sq'] = lw_down['5 year minus mar']**2

# %%
lw_down.head(60)
# Out:
#             home price    diff  home price shifted       pct  5 year shift  \
# 2001-04-01     84100.0   300.0             83800.0  0.003580       63600.0
# 2001-05-01     84200.0   100.0             84100.0  0.001189       63600.0
# 2001-06-01     84100.0  -100.0             84200.0 -0.001188       63600.0
# 2001-07-01     83900.0  -200.0             84100.0 -0.002378       63700.0
# 2001-08-01     83700.0  -200.0             83900.0 -0.002384       64000.0
# 2001-09-01     83400.0  -300.0             83700.0 -0.003584       64300.0
# 2001-10-01     83100.0  -300.0             83400.0 -0.003597       64800.0
# 2001-11-01     82900.0  -200.0             83100.0 -0.002407       65400.0
# 2001-12-01     82600.0  -300.0             82900.0 -0.003619       66000.0
# 2002-01-01     82500.0  -100.0             82600.0 -0.001211       66700.0
# 2002-02-01     82400.0  -100.0             82500.0 -0.001212       67400.0
# 2002-03-01     82400.0     0.0             82400.0  0.000000       68200.0
# 2002-04-01     82400.0     0.0             82400.0  0.000000       68900.0
# 2002-05-01     82400.0     0.0             82400.0  0.000000       69500.0
# 2002-06-01     82400.0     0.0             82400.0  0.000000       70000.0
# 2002-07-01     82500.0   100.0             82400.0  0.001214       70300.0
# 2002-08-01     82600.0   100.0             82500.0  0.001212       70600.0
# 2002-09-01     82700.0   100.0             82600.0  0.001211       70800.0
# 2002-10-01     83000.0   300.0             82700.0  0.003628       70900.0
# 2002-11-01     83400.0   400.0             83000.0  0.004819       71000.0
# 2002-12-01     83800.0   400.0             83400.0  0.004796       71000.0
# 2003-01-01     84000.0   200.0             83800.0  0.002387       71100.0
# 2003-02-01     84200.0   200.0             84000.0  0.002381       71300.0
# 2003-03-01     84300.0   100.0             84200.0  0.001188       71400.0
# 2003-04-01     84500.0   200.0             84300.0  0.002372       71500.0
# 2003-05-01     84700.0   200.0             84500.0  0.002367       71600.0
# 2003-06-01     84900.0   200.0             84700.0  0.002361       71800.0
# 2003-07-01     85100.0   200.0             84900.0  0.002356       71900.0
# 2003-08-01     85300.0   200.0             85100.0  0.002350       72000.0
# 2003-09-01     85400.0   100.0             85300.0  0.001172       72100.0
# 2003-10-01     85500.0   100.0             85400.0  0.001171       72200.0
# 2003-11-01     85500.0     0.0             85500.0  0.000000       72400.0
# 2003-12-01     85600.0   100.0             85500.0  0.001170       72700.0
# 2004-01-01     85700.0   100.0             85600.0  0.001168       72900.0
# 2004-02-01     85900.0   200.0             85700.0  0.002334       73200.0
# 2004-03-01     86200.0   300.0             85900.0  0.003492       73500.0
# 2004-04-01     86600.0   400.0             86200.0  0.004640       73900.0
# 2004-05-01     87100.0   500.0             86600.0  0.005774       74300.0
# 2004-06-01     87700.0   600.0             87100.0  0.006889       74800.0
# 2004-07-01     88400.0   700.0             87700.0  0.007982       75200.0
# 2004-08-01     89000.0   600.0             88400.0  0.006787       75700.0
# 2004-09-01     89600.0   600.0             89000.0  0.006742       76300.0
# 2004-10-01     90200.0   600.0             89600.0  0.006696       76800.0
# 2004-11-01     90700.0   500.0             90200.0  0.005543       77300.0
# 2004-12-01     91100.0   400.0             90700.0  0.004410       77800.0
# 2005-01-01     91300.0   200.0             91100.0  0.002195       78300.0
# 2005-02-01     91500.0   200.0             91300.0  0.002191       78700.0
# 2005-03-01     91600.0   100.0             91500.0  0.001093       79200.0
# 2005-04-01     91800.0   200.0             91600.0  0.002183       79600.0
# 2005-05-01     92100.0   300.0             91800.0  0.003268       80000.0
# 2005-06-01     92600.0   500.0             92100.0  0.005429       80300.0
# 2005-07-01     93300.0   700.0             92600.0  0.007559       80600.0
# 2005-08-01     94300.0  1000.0             93300.0  0.010718       81000.0
# 2005-09-01     95200.0   900.0             94300.0  0.009544       81300.0
# 2005-10-01     96100.0   900.0             95200.0  0.009454       81700.0
# 2005-11-01     96900.0   800.0             96100.0  0.008325       82200.0
# 2005-12-01     97700.0   800.0             96900.0  0.008256       82600.0
# 2006-01-01     98400.0   700.0             97700.0  0.007165       83000.0
# 2006-02-01     99100.0   700.0             98400.0  0.007114       83500.0
# 2006-03-01     99700.0   600.0             99100.0  0.006054       83800.0
#
#             5 year return        mar  5 year minus mar       neg sq
# 2001-04-01      32.232704  35.180540         -2.947835     8.689734
# 2001-05-01      32.389937  35.760117         -3.370180    11.358112
# 2001-06-01      32.232704  36.308179         -4.075474    16.609492
# 2001-07-01      31.711146  36.831948         -5.120802    26.222616
# 2001-08-01      30.781250  37.328660         -6.547410    42.868576
# 2001-09-01      29.704510  37.806995         -8.102485    65.650266
# 2001-10-01      28.240741  38.272215        -10.031475   100.630484
# 2001-11-01      26.758410  38.732499        -11.974090   143.378823
# 2001-12-01      25.151515  39.111278        -13.959763   194.874979
# 2002-01-01      23.688156  39.446022        -15.757867   248.310359
# 2002-02-01      22.255193  39.837241        -17.582048   309.128403
# 2002-03-01      20.821114  40.300376        -19.479262   379.441639
# 2002-04-01      19.593614  40.722379        -21.128766   446.424733
# 2002-05-01      18.561151  41.094230        -22.533079   507.739642
# 2002-06-01      17.714286  41.433609        -23.719324   562.606317
# 2002-07-01      17.354196  41.749079        -24.394883   595.110319
# 2002-08-01      16.997167  42.043277        -25.046110   627.307620
# 2002-09-01      16.807910  42.333816        -25.525907   651.571911
# 2002-10-01      17.066291  42.596487        -25.530196   651.790929
# 2002-11-01      17.464789  42.999513        -25.534724   652.022124
# 2002-12-01      18.028169  43.392409        -25.364240   643.344690
# 2003-01-01      18.143460  43.573264        -25.429804   646.674920
# 2003-02-01      18.092567  43.625380        -25.532814   651.924576
# 2003-03-01      18.067227  43.807389        -25.740162   662.555931
# 2003-04-01      18.181818  44.012881        -25.831063   667.243820
# 2003-05-01      18.296089  44.261400        -25.965311   674.197371
# 2003-06-01      18.245125  44.578181        -26.333056   693.429813
# 2003-07-01      18.358832  44.964674        -26.605843   707.870867
# 2003-08-01      18.472222  45.380972        -26.908749   724.080794
# 2003-09-01      18.446602  45.813284        -27.366682   748.935300
# 2003-10-01      18.421053  46.217904        -27.796851   772.664926
# 2003-11-01      18.093923  46.556678        -28.462755   810.128425
# 2003-12-01      17.744154  46.754745        -29.010591   841.614373
# 2004-01-01      17.558299  46.895444        -29.337144   860.668046
# 2004-02-01      17.349727  47.136876        -29.787149   887.274271
# 2004-03-01      17.278912  47.554395        -30.275484   916.604920
# 2004-04-01      17.185386  48.082493        -30.897107   954.631241
# 2004-05-01      17.227456  48.733520        -31.506064   992.632045
# 2004-06-01      17.245989  49.511665        -32.265676  1041.073831
# 2004-07-01      17.553191  50.373757        -32.820565  1077.189511
# 2004-08-01      17.569353  51.241107        -33.671754  1133.787006
# 2004-09-01      17.431193  52.094844        -34.663651  1201.568720
# 2004-10-01      17.447917  52.889720        -35.441803  1256.121424
# 2004-11-01      17.335058  53.568460        -36.233402  1312.859403
# 2004-12-01      17.095116  54.082690        -36.987574  1368.080624
# 2005-01-01      16.602810  54.451019        -37.848210  1432.486968
# 2005-02-01      16.264295  54.771266        -38.506971  1482.786849
# 2005-03-01      15.656566  55.197036        -39.540470  1563.448802
# 2005-04-01      15.326633  55.721874        -40.395241  1631.775456
# 2005-05-01      15.125000  56.294754        -41.169754  1694.948619
# 2005-06-01      15.317559  56.918574        -41.601015  1730.644416
# 2005-07-01      15.756824  57.566528        -41.809704  1748.051336
# 2005-08-01      16.419753  58.152274        -41.732521  1741.603276
# 2005-09-01      17.097171  58.644895        -41.547724  1726.213334
# 2005-10-01      17.625459  58.993569        -41.368110  1711.320561
# 2005-11-01      17.883212  59.159651        -41.276439  1703.744451
# 2005-12-01      18.280872  59.110053        -40.829181  1667.022034
# 2006-01-01      18.554217  58.884262        -40.330045  1626.512545
# 2006-02-01      18.682635  58.557337        -39.874702  1589.991875
# 2006-03-01      18.973747  58.276441        -39.302694  1544.701771

# %%
lw_down.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 144 entries, 2001-04-01 to 2013-12-01
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   home price          144 non-null    float64
#  1   diff                144 non-null    float64
#  2   home price shifted  144 non-null    float64
#  3   pct                 144 non-null    float64
#  4   5 year shift        144 non-null    float64
#  5   5 year return       144 non-null    float64
#  6   mar                 144 non-null    float64
#  7   5 year minus mar    144 non-null    float64
#  8   neg sq              144 non-null    float64
# dtypes: float64(9)
# memory usage: 11.2 KB

# %%
import numpy as np

np.sqrt(lw_down['neg sq'].sum()/lw_down['neg sq'].count())
# Out:
# 22.029985732397332

# %%
lw_var = lake_worth['5 year return'].dropna()

# %%
lw_var.std()
# Out:
# 85.07622645166362

# %%
lw_var.mean()
# Out:
# 54.0368829557541

# %%
lw_var.describe()
# Out:
# count    206.000000
# mean      53.871655
# std       84.901596
# min      -71.832123
# 25%      -33.036036
# 50%       57.167779
# 75%      124.909945
# max      192.718999
# Name: 5 year return, dtype: float64

# %%
lw_var.plot();

# %%
lake_worth = lake_worth.dropna()

# %%
lake_worth.head()
# Out:
#             home price   diff  home price shifted       pct
# 1996-05-01     59900.0  100.0             59800.0  0.001672
# 1996-06-01     60000.0  100.0             59900.0  0.001669
# 1996-07-01     60200.0  200.0             60000.0  0.003333
# 1996-08-01     60400.0  200.0             60200.0  0.003322
# 1996-09-01     60700.0  300.0             60400.0  0.004967

# %%
lake_worth_pct = lake_worth.drop(['home price','diff','home price shifted'],axis=1)

# %%
lake_worth_pct.head()
# Out:
#                  pct
# 1996-05-01  0.001672
# 1996-06-01  0.001669
# 1996-07-01  0.003333
# 1996-08-01  0.003322
# 1996-09-01  0.004967

# %%
lake_worth_pct = lake_worth_pct['2013-04':]

# %%
lake_worth_pct.plot();

# %%
from statsmodels.tsa.stattools import adfuller

# %%
adfuller(lake_worth_pct)
# Out:
# (-3.6685402773178515,
#  0.004578065501380513,
#  6,
#  54,
#  {'1%': -3.55770911573439,
#   '5%': -2.9167703434435808,
#   '10%': -2.59622219478738},
#  -442.20977364927535)

# %%
from sklearn.model_selection import TimeSeriesSplit
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
cutoff = '2017-05'
train = lake_worth_pct[:cutoff]
test = lake_worth_pct[cutoff:]

# %%
#Plot_acf is used to identify the q parameter
plot_acf(train);

# %%
plot_pacf(train,method='ywm')

# %%
ar_1 = ARIMA(train, order=(1, 0, 1)).fit()

# We put a typ='levels' to convert our predictions to remove the differencing performed.
train_pred = ar_1.predict()
# Out:
# /Users/johnnahra/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/johnnahra/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /Users/johnnahra/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'

# %%
from sklearn.metrics import mean_squared_error
import numpy as np

np.sqrt(mean_squared_error(train, train_pred))
# Out:
# 0.0040740516947202175

# %%
ar_1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                    pct   No. Observations:                   50
# Model:                 ARIMA(1, 0, 1)   Log Likelihood                 210.242
# Date:                Tue, 28 Mar 2023   AIC                           -412.484
# Time:                        00:56:59   BIC                           -404.836
# Sample:                    04-01-2013   HQIC                          -409.571
#                          - 05-01-2017
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0173      0.003      6.403      0.000       0.012       0.023
# ar.L1          0.6863      0.102      6.734      0.000       0.487       0.886
# ma.L1          0.6950      0.120      5.791      0.000       0.460       0.930
# sigma2      1.247e-05   2.42e-06      5.161      0.000    7.74e-06    1.72e-05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.63   Jarque-Bera (JB):                 2.80
# Prob(Q):                              0.43   Prob(JB):                         0.25
# Heteroskedasticity (H):               0.20   Skew:                             0.51
# Prob(H) (two-sided):                  0.00   Kurtosis:                         3.53
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
y_pred = ar_1.get_forecast(len(test.index))
y_pred_df = y_pred.conf_int(alpha = 0.05) 
y_pred_df["Predictions"] = ar_1.predict(start = y_pred_df.index[0], end = y_pred_df.index[-1])
y_pred_df.index = test.index
y_pred_out = y_pred_df["Predictions"]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(train, color = "black",label='Train')
plt.plot(test, color = "red",label='Test')
plt.ylabel('Monthly % Return')
plt.xlabel('Date')
plt.xticks(rotation=45)
plt.title("Train/Test split for Home Price Monthly Return Data")
plt.plot(y_pred_out, color='green', label = 'Predictions')
plt.legend();
